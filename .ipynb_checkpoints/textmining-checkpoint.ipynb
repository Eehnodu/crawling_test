# %% [markdown]
# #### 라이브러리

# %%
import pandas as pd
import csv
# 토큰 갯수세기
from collections import Counter
import re
# 반복 작업을 시각화 시켜주는 도구
from tqdm import tqdm

from konlpy.tag import Okt

# %%
data = pd.read_csv('../project_crawling/influ_fianl_data.csv')

# %%
data
# Out:
#       Unnamed: 0                      제목  \
# 0              0              사랑이 머문 자리에
# 1              1              사랑이 머문 자리에
# 2              2              사랑이 머문 자리에
# 3              3              사랑이 머문 자리에
# 4              4              사랑이 머문 자리에
# ...          ...                     ...
# 6871        6898  나만 알고 싶은 새벽감성 사클 노래 모음
# 6872        6899  나만 알고 싶은 새벽감성 사클 노래 모음
# 6873        6900  나만 알고 싶은 새벽감성 사클 노래 모음
# 6874        6901  나만 알고 싶은 새벽감성 사클 노래 모음
# 6875        6902  나만 알고 싶은 새벽감성 사클 노래 모음
#
#                                                      설명               가수  \
# 0     #팝송추천 #플레이리스트 #노래추천 우리가 함께했던 수많은 공간에는 아직도 그때의 ...  Stephen Sanchez
# 1     #팝송추천 #플레이리스트 #노래추천 우리가 함께했던 수많은 공간에는 아직도 그때의 ...  Stephen Sanchez
# 2     #팝송추천 #플레이리스트 #노래추천 우리가 함께했던 수많은 공간에는 아직도 그때의 ...  Stephen Sanchez
# 3     #팝송추천 #플레이리스트 #노래추천 우리가 함께했던 수많은 공간에는 아직도 그때의 ...       MAX, keshi
# 4     #팝송추천 #플레이리스트 #노래추천 우리가 함께했던 수많은 공간에는 아직도 그때의 ...       MAX, keshi
# ...                                                 ...              ...
# 6871  #노래추천 #음악추천 #사운드클라우드 구독자 1000명! 다들 너무 고마워요!그래서...           Mabinc
# 6872  #노래추천 #음악추천 #사운드클라우드 구독자 1000명! 다들 너무 고마워요!그래서...           Mabinc
# 6873  #노래추천 #음악추천 #사운드클라우드 구독자 1000명! 다들 너무 고마워요!그래서...         YAYYOUNG
# 6874  #노래추천 #음악추천 #사운드클라우드 구독자 1000명! 다들 너무 고마워요!그래서...         YAYYOUNG
# 6875  #노래추천 #음악추천 #사운드클라우드 구독자 1000명! 다들 너무 고마워요!그래서...         YAYYOUNG
#
#                                                 곡명   이미지객체            이미지색감  \
# 0                                Until I Found You  person      [7, 10, 13]
# 1                                Until I Found You  person   [83, 138, 161]
# 2                                Until I Found You  person     [18, 50, 83]
# 3                                         IT'S YOU  person      [7, 10, 13]
# 4                                         IT'S YOU  person   [83, 138, 161]
# ...                                            ...     ...              ...
# 6871                            혼잣말 (feat. Ripley)     NaN  [134, 134, 134]
# 6872                            혼잣말 (feat. Ripley)     NaN  [218, 218, 218]
# 6873  do you feel like you have no one to turn to?     NaN  [204, 204, 204]
# 6874  do you feel like you have no one to turn to?     NaN  [134, 134, 134]
# 6875  do you feel like you have no one to turn to?     NaN  [219, 219, 219]
#
#            색감비율
# 0     53.587348
# 1     32.854709
# 2     13.557943
# 3     53.587457
# 4     32.854709
# ...         ...
# 6871  16.962963
# 6872   9.138889
# 6873  75.185185
# 6874  16.962963
# 6875   7.851852
#
# [6876 rows x 8 columns]

# %%
# 각 범위 내 첫 번째 행만 남기고 삭제할 인덱스 계산
indexes_to_drop = []

# 예를 들어 6개의 행이 있고, 각 범위가 3행이라고 할 때,
# 0~2에서 1, 2 삭제하고, 3~5에서 4, 5를 삭제
for i in range(0, len(data), 3):  # 여기서 3은 범위의 크기입니다.
    if i + 1 < len(data): indexes_to_drop.append(i + 1)
    if i + 2 < len(data): indexes_to_drop.append(i + 2)

# 계산된 인덱스에 해당하는 행 삭제
data = data.drop(indexes_to_drop)
data
# Out:
#       Unnamed: 0                      제목  \
# 0              0              사랑이 머문 자리에
# 3              3              사랑이 머문 자리에
# 6              6              사랑이 머문 자리에
# 9              9              사랑이 머문 자리에
# 12            12              사랑이 머문 자리에
# ...          ...                     ...
# 6861        6888  나만 알고 싶은 새벽감성 사클 노래 모음
# 6864        6891  나만 알고 싶은 새벽감성 사클 노래 모음
# 6867        6894  나만 알고 싶은 새벽감성 사클 노래 모음
# 6870        6897  나만 알고 싶은 새벽감성 사클 노래 모음
# 6873        6900  나만 알고 싶은 새벽감성 사클 노래 모음
#
#                                                      설명  \
# 0     #팝송추천 #플레이리스트 #노래추천 우리가 함께했던 수많은 공간에는 아직도 그때의 ...
# 3     #팝송추천 #플레이리스트 #노래추천 우리가 함께했던 수많은 공간에는 아직도 그때의 ...
# 6     #팝송추천 #플레이리스트 #노래추천 우리가 함께했던 수많은 공간에는 아직도 그때의 ...
# 9     #팝송추천 #플레이리스트 #노래추천 우리가 함께했던 수많은 공간에는 아직도 그때의 ...
# 12    #팝송추천 #플레이리스트 #노래추천 우리가 함께했던 수많은 공간에는 아직도 그때의 ...
# ...                                                 ...
# 6861  #노래추천 #음악추천 #사운드클라우드 구독자 1000명! 다들 너무 고마워요!그래서...
# 6864  #노래추천 #음악추천 #사운드클라우드 구독자 1000명! 다들 너무 고마워요!그래서...
# 6867  #노래추천 #음악추천 #사운드클라우드 구독자 1000명! 다들 너무 고마워요!그래서...
# 6870  #노래추천 #음악추천 #사운드클라우드 구독자 1000명! 다들 너무 고마워요!그래서...
# 6873  #노래추천 #음악추천 #사운드클라우드 구독자 1000명! 다들 너무 고마워요!그래서...
#
#                                           가수  \
# 0                            Stephen Sanchez
# 3                                 MAX, keshi
# 6                                      keshi
# 9                                Arash Buana
# 12    Jesse Barrera, Nieman, Melissa Polinar
# ...                                      ...
# 6861                                 Bas Bao
# 6864                               D'sperado
# 6867                                    Dvwn
# 6870                                  Mabinc
# 6873                                YAYYOUNG
#
#                                                   곡명   이미지객체            이미지색감  \
# 0                                  Until I Found You  person      [7, 10, 13]
# 3                                           IT'S YOU  person      [7, 10, 13]
# 6                                         UNDERSTAND  person      [7, 10, 13]
# 9                                              stars  person      [7, 10, 13]
# 12                           Tangled Up (Reimagined)  person      [7, 10, 13]
# ...                                              ...     ...              ...
# 6861                                     넌 없고, 난 머물고     NaN  [204, 204, 204]
# 6864                      O/W (with hatts, HYE SUNG)     NaN  [204, 204, 204]
# 6867  불면증 (白夜) (feat. YAYYOUNG) (prod. by N O V E L)     NaN  [204, 204, 204]
# 6870                              혼잣말 (feat. Ripley)     NaN  [204, 204, 204]
# 6873    do you feel like you have no one to turn to?     NaN  [204, 204, 204]
#
#            색감비율
# 0     53.587348
# 3     53.587457
# 6     53.587348
# 9     53.589518
# 12    53.565972
# ...         ...
# 6861  75.185185
# 6864  73.898148
# 6867  75.185185
# 6870  73.898148
# 6873  75.185185
#
# [2292 rows x 8 columns]

# %%
title_text = data['제목']
explain_text = data['설명']

# %%
title_tmp = [doc.split(" ") for doc in title_text]
explain_tmp = [doc.split(" ") for doc in explain_text]

# %%
my_okt = Okt()  # 형태소분석기 객체 생성

# %%
title_morphs = []
for txt in tqdm(title_text):  # 훈련용 문장을 반복
    morphs = my_okt.pos(txt)  # 각 문장을 형태소와 품사 태그로 분리
    filtered_morphs = [word for word, tag in morphs if tag in ['Noun', 'Adjective']]  # 명사와 형용사만 필터링
    title_morphs.append(filtered_morphs)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 2292/2292 [00:02<00:00, 893.35it/s]

# %%
title_morphs
# Out:
# [['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['사랑', '자리'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['너', '점철', '밤'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['생각', '당신'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['너', '잔잔한', '위로'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['나른한', '오후', '피크닉'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['햇살', '좋은데', '집', '있을'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['싫어'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['봄', '온'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['그냥', '네', '생각'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['따뜻한', '오후', '햇살', '아래'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['시리', '시린', '계절', '겨울'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['너', '자장가'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['올드', '재즈', '레스토랑', '레이'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['파리', '크리스마스', '그', '낭만', '거리', '미셸', '들라크루아'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['너', '위해', '온', '크리스마스'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['우리', '겨울', '밤', '잔잔한', '재즈'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['크리스마스', '기적'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['너', '크리스마스', '선물'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['눈', '우리'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['어느새', '겨울', '재즈', '계절'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['너', '파도처럼', '내게로'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['다시금', '꽃처럼'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['사랑', '이름'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['바쁜', '일상', '속', '여유', '필요해'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['그대', '좋아하는', '가을', '요'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['이런', '노래', '하루', '가득'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['여름', '정점', '향'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['그', '해', '여름', '해변', '노을', '아름다웠다'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['너', '존재', '안도'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['비', '날', '수채화'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['어디', '로'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['파리', '아침', '강', '여유'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['우리', '사랑', '잔잔한', '물결'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['짙게', '물든', '하늘', '가볍게', '마음'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['햇살', '따스했던', '나른한', '오후'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ['피크닉', '가기', '좋은', '날씨'],
#  ...]

# %%
explain_morphs = []
for txt in tqdm(explain_text):  # 훈련용 문장을 반복
    morphs = my_okt.pos(txt)  # 각 문장을 형태소와 품사 태그로 분리
    filtered_morphs = [word for word, tag in morphs if tag in ['Noun', 'Adjective']]  # 명사와 형용사만 필터링
    explain_morphs.append(filtered_morphs)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 2292/2292 [00:10<00:00, 223.22it/s]

# %%
explain_morphs
# Out:
# [['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['우리', '수많은', '공간', '그때', '사랑', '있을까'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['그런', '밤'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['생각', '정리', '필요한', '오늘'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['가끔',
#   '너',
#   '인생',
#   '벅차',
#   '끊임없이',
#   '인생',
#   '시련',
#   '그',
#   '속',
#   '너',
#   '마치',
#   '금방',
#   '것',
#   '같은',
#   '팽이',
#   '위태롭',
#   '버티고',
#   '있는지도',
#   '그래',
#   '시련',
#   '파도',
#   '같아서',
#   '매몰',
#   '너',
#   '때로는',
#   '해일',
#   '시련',
#   '깊은',
#   '절망',
#   '복판',
#   '때',
#   '있겠지',
#   '피',
#   '결코',
#   '피',
#   '수',
#   '없는',
#   '인생',
#   '시련',
#   '두려움',
#   '이내',
#   '발걸음',
#   '너',
#   '진정한',
#   '두려움',
#   '것',
#   '아니라',
#   '두려움',
#   '속',
#   '것임',
#   '너',
#   '그',
#   '안개',
#   '자욱한',
#   '길',
#   '속',
#   '주위',
#   '조심',
#   '걸음',
#   '또',
#   '걸음',
#   '어느새',
#   '안개',
#   '아름다운',
#   '광경',
#   '선명히',
#   '것',
#   '너',
#   '분명히',
#   '알',
#   '있기에',
#   '태풍',
#   '자리',
#   '다시',
#   '새로운',
#   '생명',
#   '시련',
#   '비',
#   '너',
#   '다시금',
#   '새로운',
#   '희망이',
#   '피어',
#   '좋겠다',
#   '소담',
#   '스레',
#   '피어',
#   '너',
#   '희망이',
#   '지지',
#   '채',
#   '짙은',
#   '향기',
#   '마음껏',
#   '좋겠다',
#   '고막'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['날씨', '좋은데', '피크닉'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['고막',
#   '셀',
#   '퓨전',
#   '영상',
#   '제공',
#   '이종범',
#   '작가',
#   '햇빛',
#   '좋지만',
#   '자외선',
#   '싫어',
#   '햇빛',
#   '필요한',
#   '순간',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '하자',
#   '햇빛',
#   '지하방',
#   '잠깐',
#   '햇빛',
#   '소중하지만',
#   '뜨거운',
#   '자외선',
#   '걱정',
#   '하루',
#   '종일',
#   '있는',
#   '사무실',
#   '비타민',
#   '충전',
#   '위해',
#   '산책',
#   '자외선',
#   '차단',
#   '필요하죠',
#   '누구',
#   '햇빛',
#   '필요한',
#   '순간',
#   '많다',
#   '햇빛',
#   '연구소',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '때',
#   '좋은',
#   '플레이',
#   '리스트',
#   '준비',
#   '독자',
#   '댓글',
#   '이벤트',
#   '총',
#   '명',
#   '참여',
#   '방법',
#   '플레이',
#   '리스트',
#   '햇빛',
#   '나',
#   '방법',
#   '댓글',
#   '예',
#   '회사',
#   '점심시간',
#   '산책',
#   '광합성',
#   '충전',
#   '기간',
#   '수',
#   '오후',
#   '목',
#   '자정',
#   '당첨',
#   '발표',
#   '화',
#   '선정',
#   '여러분',
#   '햇빛',
#   '수',
#   '있도록',
#   '셀',
#   '퓨전',
#   '햇빛',
#   '케어',
#   '제품'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['싫은데', '노래'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['사랑'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['어서', '온'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['그냥', '그랬어'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['봄', '사진', '제공', '신현빈', '작가'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
#  ['영화', '터널', '선샤인', '과'],
# ...
#  ['네', '있어', '다행'],
#  ['네', '있어', '다행'],
#  ['네', '있어', '다행'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['미온수', '따뜻한', '여름', '비', '린다'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['생각',
#   '기분',
#   '여행',
#   '설레는',
#   '여행',
#   '길',
#   '플레이',
#   '리스트',
#   '백화점',
#   '면세점',
#   '책',
#   '지금',
#   '백화점',
#   '면세점',
#   '평생',
#   '회원',
#   '가입',
#   '온',
#   '오프라인',
#   '멤버십',
#   '등급',
#   '업그레이드',
#   '기회'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['우리', '사랑', '아주', '잔잔히', '서로', '끊임없이', '렁'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['선선', '저녁', '이런', '노래', '어때'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  ['햇살', '좋을', '땐', '역시', '이런', '노래'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
# 한글자 제거 및 정규표현식 활용 불필요한 토큰 삭제
import re # 정규표현식
p = re.compile("[ㅋㅇㅎㄷ~ㅡ>:#!.?,0-9a-z]+")  # 정규표현식 패턴

# %%
title_clean_text = []  # 전처리된 결과가 들어갈 리스트
# 한 글자 단어 삭제
for sentence in tqdm(title_morphs):  # 한 문장씩 꺼내오는 반복문
    tmp = []
    for token in sentence :   # 형태소 단위로 쪼개진 토큰을 반복
        # if len(token) < 2:  # 1글자 제거
        #     continue
        if p.match(token):  # 정규표현식에 매칭되는 글자 제거
            continue
        tmp.append(token)  # 나머지 정상 토큰을 리스트에 등록
    title_clean_text.append(tmp)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 2292/2292 [00:00<00:00, 469699.75it/s]

# %%
explain_clean_text = []
# 한 글자 단어 삭제
for sentence in tqdm(explain_morphs):  # 한 문장씩 꺼내오는 반복문
    tmp = []
    for token in sentence :   # 형태소 단위로 쪼개진 토큰을 반복
        # if len(token) < 2:  # 1글자 제거
        #     continue
        if p.match(token):  # 정규표현식에 매칭되는 글자 제거
            continue
        tmp.append(token)  # 나머지 정상 토큰을 리스트에 등록
    explain_clean_text.append(tmp)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 2292/2292 [00:00<00:00, 180671.40it/s]

# %%
# 하나의 리스트로 모아주기
title_token_list = []
explain_token_list = []
for s in title_clean_text:
    title_token_list += s
for s in explain_clean_text:
    explain_token_list += s

# %%
title_counter = Counter(title_token_list)

# %%
title_counter
# Out:
# Counter({'너': 530,
#          '사랑': 197,
#          '재즈': 191,
#          '노래': 180,
#          '크리스마스': 153,
#          '오후': 133,
#          '우리': 127,
#          '봄': 125,
#          '잔잔한': 119,
#          '햇살': 118,
#          '밤': 108,
#          '겨울': 96,
#          '가을': 93,
#          '네': 92,
#          '오늘': 86,
#          '이': 85,
#          '피크닉': 83,
#          '계절': 83,
#          '그': 82,
#          '나': 81,
#          '여름': 77,
#          '온': 76,
#          '위해': 72,
#          '아침': 72,
#          '낭만': 69,
#          '모든': 69,
#          '나른한': 67,
#          '파리': 66,
#          '여유': 66,
#          '해': 65,
#          '날': 63,
#          '마음': 62,
#          '선물': 59,
#          '새벽': 57,
#          '지금': 56,
#          '모음': 56,
#          '하루': 54,
#          '생각': 52,
#          '위로': 52,
#          '속': 49,
#          '기억': 47,
#          '노을': 46,
#          '가장': 46,
#          '행복': 46,
#          '감성': 46,
#          '거리': 45,
#          '말': 45,
#          '사람': 45,
#          '사': 45,
#          '비': 44,
#          '좋은': 44,
#          '이런': 43,
#          '잠시': 43,
#          '어디': 42,
#          '가득': 41,
#          '간다': 40,
#          '저': 40,
#          '일상': 39,
#          '그냥': 38,
#          '문득': 38,
#          '아래': 37,
#          '자장가': 37,
#          '조금': 37,
#          '가볍게': 36,
#          '미셸': 34,
#          '들라크루아': 34,
#          '물결': 34,
#          '올드': 33,
#          '레스토랑': 33,
#          '레이': 33,
#          '수고': 33,
#          '싫어': 32,
#          '좋은데': 31,
#          '집': 31,
#          '있을': 31,
#          '강': 31,
#          '로': 30,
#          '정점': 29,
#          '향': 29,
#          '설렌다': 29,
#          '또': 29,
#          '시간': 29,
#          '자리': 28,
#          '따뜻한': 28,
#          '파도처럼': 28,
#          '내게로': 28,
#          '수채화': 28,
#          '작은': 28,
#          '것': 28,
#          '점철': 27,
#          '기적': 27,
#          '어느새': 27,
#          '존재': 27,
#          '안도': 27,
#          '따스했던': 27,
#          '바로': 27,
#          '완벽한': 27,
#          '플레이': 27,
#          '리스트': 27,
#          '있는': 27,
#          '여름날': 27,
#          '엄마': 27,
#          '커피': 27,
#          '귀로': 27,
#          '퇴근길': 27,
#          '짙게': 26,
#          '물든': 26,
#          '하늘': 26,
#          '온통': 26,
#          '알': 26,
#          '당신': 25,
#          '시리': 25,
#          '시린': 25,
#          '눈': 25,
#          '이름': 25,
#          '초저녁': 25,
#          '로맨스': 25,
#          '걱정': 25,
#          '다시금': 24,
#          '꽃처럼': 24,
#          '가기': 24,
#          '날씨': 24,
#          '꽃': 24,
#          '그대': 23,
#          '좋아하는': 23,
#          '요': 23,
#          '해변': 23,
#          '아름다웠다': 23,
#          '설레어서': 22,
#          '란': 22,
#          '주말': 22,
#          '비극': 21,
#          '안': 20,
#          '분위기': 20,
#          '소리': 20,
#          '아름다운': 19,
#          '나로': 18,
#          '충분히': 18,
#          '괜찮은': 18,
#          '가까운': 18,
#          '곳': 18,
#          '마지막': 17,
#          '아름답게': 17,
#          '항상': 17,
#          '쉿': 16,
#          '위': 16,
#          '아주': 16,
#          '근사한': 16,
#          '듣기': 16,
#          '음악': 16,
#          '없다면': 16,
#          '인생': 16,
#          '실수': 16,
#          '일': 16,
#          '뿐': 16,
#          '음': 15,
#          '약속': 14,
#          '취소': 14,
#          '시시한': 14,
#          '쉼표': 14,
#          '필요하니까': 14,
#          '특별해질': 14,
#          '지도': 14,
#          '카페': 14,
#          '힙합': 14,
#          '려고': 14,
#          '멜로디': 13,
#          '이야기': 13,
#          '때로는': 13,
#          '호수': 13,
#          '저기': 13,
#          '혹시': 13,
#          '좋아하세요': 13,
#          '론': 12,
#          '훌쩍': 12,
#          '뭐': 12,
#          '이쁜': 12,
#          '거': 12,
#          '거림': 12,
#          '사랑스러운': 12,
#          '바쁜': 11,
#          '필요해': 11,
#          '바보': 11,
#          '무심코': 11,
#          '근사해져': 11,
#          '여름밤': 11,
#          '틀': 11,
#          '니': 11,
#          '꼭': 11,
#          '따스한': 11,
#          '같아': 11,
#          '찬': 11,
#          '기운': 11,
#          '있었으면': 11,
#          '좋겠어': 11,
#          '마치': 10,
#          '영화': 10,
#          '장면': 10,
#          '잠': 10,
#          '노랠': 10,
#          '깊어가는': 10,
#          '오묘한': 10,
#          '있더라': 10,
#          '귓가': 10,
#          '벽감': 10,
#          '안녕': 10,
#          '우울': 10,
#          '무슨': 10,
#          '설렘으로': 10,
#          '가득하길': 10,
#          '어땠어': 10,
#          '감정': 10,
#          '렁': 10,
#          '화창한': 10,
#          '텐션': 10,
#          '업': 10,
#          '순간': 10,
#          '시작': 10,
#          '팝송': 10,
#          '요즘': 9,
#          '어때': 9,
#          '갑자기': 9,
#          '오늘밤': 9,
#          '캘리포니아': 9,
#          '번': 9,
#          '국도': 9,
#          '싱그러운': 9,
#          '미소': 9,
#          '사운드클라우드': 9,
#          '담담하게': 7,
#          '이별': 7,
#          '초여름': 3,
#          '방법': 3,
#          '버거울지라도': 1,
#          '무드': 1,
#          '한적한': 1,
#          '강가': 1,
#          '향기': 1,
#          '머': 1,
#          '금은': 1,
#          '베이커': 1,
#          '목소리': 1})

# %%
explain_counter = Counter(explain_token_list)

# %%
explain_counter
# Out:
# Counter({'노래': 520,
#          '사랑': 424,
#          '너': 422,
#          '햇빛': 341,
#          '플레이': 318,
#          '리스트': 318,
#          '수': 278,
#          '파리': 277,
#          '전시': 255,
#          '베이': 252,
#          '지크': 252,
#          '고막': 233,
#          '것': 229,
#          '순간': 209,
#          '이벤트': 204,
#          '우리': 198,
#          '독자': 190,
#          '여름': 186,
#          '재즈': 178,
#          '책': 175,
#          '이': 175,
#          '겨울': 173,
#          '사람': 173,
#          '케어': 166,
#          '때': 164,
#          '인스타그램': 156,
#          '여행': 156,
#          '댓글': 150,
#          '좋은': 149,
#          '속': 148,
#          '작가': 145,
#          '또': 139,
#          '그': 138,
#          '길': 131,
#          '인생': 127,
#          '입니다': 127,
#          '사진': 126,
#          '시련': 125,
#          '온': 125,
#          '기억': 125,
#          '셀': 124,
#          '퓨전': 124,
#          '피부': 124,
#          '백화점': 122,
#          '면세점': 122,
#          '이번': 120,
#          '시간': 113,
#          '지금': 113,
#          '이런': 110,
#          '두려움': 109,
#          '생각': 108,
#          '밤': 104,
#          '스킨': 104,
#          '미셸': 102,
#          '들라크루아': 102,
#          '마음': 102,
#          '커피': 102,
#          '말': 100,
#          '하루': 97,
#          '준비': 96,
#          '방법': 96,
#          '따뜻한': 96,
#          '연작': 96,
#          '꽃': 96,
#          '봄': 95,
#          '게시': 95,
#          '물': 95,
#          '감성': 94,
#          '자외선': 93,
#          '있는': 93,
#          '브랜드': 93,
#          '마지막': 93,
#          '총': 92,
#          '있도록': 92,
#          '가장': 89,
#          '참여': 88,
#          '출처': 88,
#          '필요한': 87,
#          '의': 87,
#          '그림': 87,
#          '역시': 86,
#          '카페': 84,
#          '영상': 83,
#          '아름다운': 82,
#          '나': 81,
#          '기분': 80,
#          '당신': 80,
#          '오늘': 79,
#          '진행': 78,
#          '크리스마스': 78,
#          '내': 77,
#          '잠시': 76,
#          '걱정': 74,
#          '마음껏': 73,
#          '오후': 73,
#          '소중한': 73,
#          '전하': 72,
#          '자연': 72,
#          '작품': 72,
#          '가을': 72,
#          '분': 70,
#          '위해': 68,
#          '여러분': 68,
#          '더': 68,
#          '헤': 68,
#          '딜러': 68,
#          '누구': 67,
#          '새로운': 66,
#          '꽉': 66,
#          '눈': 66,
#          '있습니다': 66,
#          '맞이': 64,
#          '그런': 63,
#          '좋겠다': 63,
#          '채': 63,
#          '포함': 63,
#          '가끔': 62,
#          '충전': 62,
#          '산책': 62,
#          '점': 62,
#          '선물': 62,
#          '설레는': 61,
#          '평생': 61,
#          '회원': 61,
#          '가입': 61,
#          '오프라인': 61,
#          '멤버십': 61,
#          '등급': 61,
#          '업그레이드': 61,
#          '기회': 61,
#          '피크닉': 59,
#          '제공': 59,
#          '어서': 59,
#          '당첨': 58,
#          '한국': 58,
#          '공간': 56,
#          '듣기': 56,
#          '해도': 56,
#          '비건': 56,
#          '를': 56,
#          '오픈': 56,
#          '같은': 54,
#          '스포티파이': 54,
#          '어떤': 54,
#          '더블유': 54,
#          '윈저': 54,
#          '파도': 53,
#          '비': 53,
#          '자리': 52,
#          '위': 52,
#          '공식': 52,
#          '홈페이지': 52,
#          '선명히': 51,
#          '날씨': 51,
#          '이상': 51,
#          '통해': 51,
#          '티켓': 51,
#          '저녁': 51,
#          '방문': 51,
#          '차': 51,
#          '피': 50,
#          '안개': 50,
#          '걸음': 50,
#          '희망이': 50,
#          '피어': 50,
#          '끊임없이': 49,
#          '다시금': 49,
#          '기간': 48,
#          '바탕': 48,
#          '선곡': 48,
#          '차단': 47,
#          '콘텐츠': 47,
#          '제작': 47,
#          '유료': 47,
#          '광고': 47,
#          '다시': 46,
#          '이제': 46,
#          '사운드': 46,
#          '바': 46,
#          '신제품': 46,
#          '채널': 46,
#          '꼭': 45,
#          '날': 45,
#          '색': 45,
#          '작은': 45,
#          '명': 44,
#          '곧': 44,
#          '여유': 44,
#          '그랬어': 43,
#          '자신': 43,
#          '가득': 43,
#          '낭만': 43,
#          '수고': 43,
#          '앞': 43,
#          '곡': 43,
#          '없는': 42,
#          '노을': 42,
#          '몸': 42,
#          '업로드': 42,
#          '제': 40,
#          '프리미엄': 40,
#          '주말': 40,
#          '언제': 39,
#          '햇살': 39,
#          '알': 38,
#          '뜻': 38,
#          '약속': 38,
#          '보시': 38,
#          '빛': 38,
#          '행복': 38,
#          '완성': 38,
#          '야경': 38,
#          '가치': 37,
#          '아주': 37,
#          '선선': 37,
#          '네': 36,
#          '아름답게': 36,
#          '나로': 36,
#          '충분히': 36,
#          '괜찮은': 36,
#          '새벽': 36,
#          '영화': 35,
#          '어때': 35,
#          '조금': 35,
#          '벨': 34,
#          '포크': 34,
#          '초대': 34,
#          '프랑스': 34,
#          '대표': 34,
#          '화가': 34,
#          '탄생': 34,
#          '주년': 34,
#          '최대': 34,
#          '규모': 34,
#          '예술의전당': 34,
#          '한가람': 34,
#          '디자인': 34,
#          '미술관': 34,
#          '리지': 34,
#          '널': 34,
#          '페인팅': 34,
#          '가지': 34,
#          '주제': 34,
#          '고스': 34,
#          '란': 34,
#          '있는데요': 34,
#          '가야': 34,
#          '분과': 34,
#          '관람객': 34,
#          '사람과': 34,
#          '어떤지요': 34,
#          '연인': 34,
#          '친구': 34,
#          '가족': 34,
#          '볼': 34,
#          '유튜브': 34,
#          '인': 34,
#          '매': 34,
#          '동심': 34,
#          '잔뜩': 34,
#          '포근한': 34,
#          '해당': 34,
#          '작성': 34,
#          '계정': 34,
#          '힐링': 34,
#          '서비스': 34,
#          '점점': 34,
#          '두': 34,
#          '배우': 34,
#          '연애': 34,
#          '섹스': 34,
#          '관람': 34,
#          '올드': 33,
#          '게스트': 33,
#          '레이': 33,
#          '전': 33,
#          '신경': 33,
#          '싫은데': 32,
#          '세상': 32,
#          '이종범': 31,
#          '좋지만': 31,
#          '싫어': 31,
#          '하자': 31,
#          '지하방': 31,
#          '잠깐': 31,
#          '소중하지만': 31,
#          '뜨거운': 31,
#          '종일': 31,
#          '사무실': 31,
#          '비타민': 31,
#          '필요하죠': 31,
#          '많다': 31,
#          '연구소': 31,
#          '예': 31,
#          '회사': 31,
#          '점심시간': 31,
#          '광합성': 31,
#          '목': 31,
#          '자정': 31,
#          '발표': 31,
#          '화': 31,
#          '선정': 31,
#          '제품': 31,
#          '신현빈': 31,
#          '잔잔한': 31,
#          '인스타': 30,
#          '끝': 30,
#          '달': 30,
#          '듯': 30,
#          '좋은데': 29,
#          '정점': 29,
#          '시원해지는': 29,
#          '위로': 29,
#          '설렌다': 29,
#          '선택': 29,
#          '저': 29,
#          '있던': 29,
#          '중': 29,
#          '수많은': 28,
#          '그때': 28,
#          '있을까': 28,
#          '미온수': 28,
#          '린다': 28,
#          '바쁜': 28,
#          '일상': 28,
#          '휴식': 28,
#          '잔': 28,
#          '베이지': 28,
#          '연희동': 28,
#          '첫': 28,
#          '플래그': 28,
#          '스토어': 28,
#          '무드': 28,
#          '핵심': 28,
#          '원료': 28,
#          '그린': 28,
#          '커피빈': 28,
#          '나무': 28,
#          '특별한': 28,
#          '에너지': 28,
#          '경험': 28,
#          '위치': 28,
#          '연희': 28,
#          '층': 28,
#          '평일': 28,
#          '캐롤': 28,
#          '그냥': 27,
#          '굿나잇': 27,
#          '초청': 27,
#          '만날': 27,
#          '마련': 27,
#          '추첨': 27,
#          '동반': 27,
#          '인과': 27,
#          '파티': 27,
#          '한해': 27,
#          '개별': 27,
#          '계절': 27,
#          '있어': 27,
#          '다행': 27,
#          '좋을': 27,
#          '땐': 27,
#          '잔잔하게': 27,
#          '있나요': 27,
#          '휴가': 27,
#          '얘': 27,
#          '세': 27,
#          '주': 27,
#          '복판': 26,
#          '간다': 26,
#          '커먼': 26,
#          '많은': 26,
#          '회수': 26,
#          '정리': 25,
#          '벅차': 25,
#          '마치': 25,
#          '금방': 25,
#          '팽이': 25,
#          '위태롭': 25,
#          '버티고': 25,
#          '있는지도': 25,
#          '그래': 25,
#          '같아서': 25,
#          '매몰': 25,
#          '때로는': 25,
#          '해일': 25,
#          '깊은': 25,
#          '절망': 25,
#          '있겠지': 25,
#          '결코': 25,
#          '이내': 25,
#          '발걸음': 25,
#          '진정한': 25,
#          '아니라': 25,
#          '것임': 25,
#          '자욱한': 25,
#          '주위': 25,
#          '조심': 25,
#          '어느새': 25,
#          '광경': 25,
#          '분명히': 25,
#          '있기에': 25,
#          '태풍': 25,
#          '생명': 25,
#          '소담': 25,
#          '스레': 25,
#          '지지': 25,
#          '짙은': 25,
#          '향기': 25,
#          '터널': 25,
#          '선샤인': 25,
#          '과': 25,
#          '이름': 25,
#          '기운': 25,
#          '도': 25,
#          '영감': 24,
#          '은': 24,
#          '식물': 24,
#          '자생': 24,
#          '전달': 24,
#          '뿌리': 24,
#          '줄기': 24,
#          '전초': 24,
#          '겹': 24,
#          '더해': 24,
#          '건강한': 24,
#          '자체': 24,
#          '꽃처럼': 24,
#          '스스로': 24,
#          '롯': 24,
#          '잔잔히': 24,
#          '서로': 24,
#          '렁': 24,
#          '그대': 24,
#          '있고': 24,
#          '있지': 24,
#          '좋아하고': 24,
#          '그리워하세요': 24,
#          '나태주': 24,
#          '깊어져라': 23,
#          '바다': 23,
#          '소개': 23,
#          '전자': 23,
#          '지원': 23,
#          '런칭': 23,
#          '기념': 23,
#          '출시': 23,
#          '특별': 23,
#          '네이버': 23,
#          '선셋': 23,
#          '바이브': 23,
#          '앨범': 23,
#          '작업': 23,
#          '설': 22,
#          '레일': 22,
#          '있잖아요': 22,
#          '시작': 22,
#          '느낌': 22,
#          '분위기': 21,
#          '적': 20,
#          '성': 20,
#          '수정': 20,
#          '추억': 19,
#          '쓰나미': 19,
#          '고향': 19,
#          '벚꽃': 19,
#          '그리워한': 19,
#          '노인': 19,
#          '못': 19,
#          '청년': 19,
#          '의지': 19,
#          '처음': 19,
#          '죽음': 19,
#          '여학생': 19,
#          '시각장애인': 19,
#          '있었던': 19,
#          '소녀': 19,
#          '등': 19,
#          '사신': 19,
#          '영혼': 19,
#          '책장': 19,
#          '찬란한': 19,
#          '애절한': 19,
#          '무엇': 19,
#          '없다': 19,
#          '노력': 18,
#          '김재식': 18,
#          '문장': 18,
#          '행복하자': 18,
#          '나른한': 18,
#          '한잔': 18,
#          '같': 18,
#          '괜찮아': 18,
#          '헤어지자': 17,
#          '부디': 17,
#          '값': 17,
#          '어렵고': 17,
#          '불편하던': 17,
#          '기': 17,
#          '혁신': 17,
#          '앱': 17,
#          '과정': 17,
#          '같습니다': 17,
#          '모델': 17,
#          '김혜수': 17,
#          '소희': 17,
#          '캠페인': 17,
#          '필름': 17,
#          '변화': 17,
#          '쿨한': 17,
#          '감상': 17,
#          '웨이즈': 17,
#          '유': 17,
#          '있지만': 17,
#          '모두': 17,
#          '절대': 17,
#          '혼자': 17,
#          '없기에': 17,
#          '더욱더': 17,
#          '어렵게': 17,
#          '기도': 17,
#          '건': 17,
#          '힘든': 17,
#          '시대': 17,
#          '그럼에도': 17,
#          '불구': 17,
#          '고': 17,
#          '오직': 17,
#          '인간': 17,
#          '답': 17,
#          '내일': 17,
#          '기대하게': 17,
#          '원동력': 17,
#          '때문': 17,
#          '청소년': 17,
#          '불가': 17,
#          '가능': 17,
#          '장소': 17,
#          '라운드': 17,
#          '시소': 17,
#          '촌': 17,
#          '서울시': 17,
#          '종로구': 17,
#          '자하문로': 17,
#          '변동': 17,
#          '가능성': 17,
#          '있음': 17,
#          '대상': 17,
#          '레드': 17,
#          '룸': 17,
#          '할인': 17,
#          '장마': 16,
#          '걸': 16,
#          '항상': 16,
#          '거지': 16,
#          '기존': 16,
#          '궁금해': 16,
#          '저작권': 16,
#          '취급': 16,
#          '방식': 16,
#          '변경': 16,
#          '스트레스': 16,
#          '고민': 16,
#          '제외': 16,
#          '번': 16,
#          '업데이트': 16,
#          '추가': 16,
#          '재': 16,
#          '문제': 16,
#          '부분': 16,
#          '전혀': 16,
#          '없으니': 16,
#          '고요': 14,
#          '때내': 14,
#          '곁': 14,
#          '있을게요': 14,
#          '취소': 14,
#          '행복해진다': 14,
#          '그럴지도': 14,
#          '어디': 14,
#          '없을까': 14,
#          '요런': 14,
#          '아마': 14,
#          '없을걸': 14,
#          '뻔하지': 14,
#          '채운': 14,
#          '즐감': 14,
#          '바람결': 13,
#          '조용히': 13,
#          '만': 13,
#          '자극': 13,
#          '호수': 13,
#          '좋아하시냐': 13,
#          '구': 13,
#          '높은': 13,
#          '기록': 13,
#          '사': 13,
#          '모음': 13,
#          '고마워요': 13,
#          '가득한': 13,
#          '개인': 13,
#          '취향': 13,
#          '듬뿍': 13,
#          '추리': 13,
#          '후회': 13,
#          '없을거에요': 13,
#          '트랙': 13,
#          '순서도': 13,
#          '맘': 13,
#          '스코틀랜드': 12,
#          '정통': 12,
#          '수제': 12,
#          '싱글': 12,
#          '몰트': 12,
#          '위스키': 12,
#          '발': 12,
#          '베니': 12,
#          '새해': 12,
#          '술': 12,
#          '음악': 12,
#          '더욱': 12,
#          '따뜻해지는': 12,
#          '여행가': 12,
#          '아침': 12,
#          '따스한': 12,
#          '침대': 12,
#          '게으름': 12,
#          '왜케': 11,
#          '그런거야': 11,
#          '그동안': 11,
#          '평소': 11,
#          '다르게': 11,
#          '다양한': 11,
#          '믹스': 11,
#          '둘': 11,
#          '퇴근길': 11,
#          '게': 11,
#          '모든': 11,
#          '강박': 11,
#          '변태': 11,
#          '끼': 11,
#          '발동': 11,
#          '겨우': 11,
#          '플리': 11,
#          '바람': 11,
#          '타고': 11,
#          '여름밤': 11,
#          '슬슬': 11,
#          '그럴': 11,
#          '같아': 11,
#          '급': 11,
#          '그랬음': 11,
#          '좋겠어': 11,
#          '최애': 10,
#          '어바웃타임': 10,
#          '당장': 10,
#          '주섬주섬': 10,
#          '혼': 10,
#          '드림': 10,
#          '딧': 10,
#          '단단히': 10,
#          '나머지': 10,
#          '최대한': 10,
#          '태식': 10,
#          '성진': 10,
#          '랄': 10,
#          '미완': 10,
#          '데': 10,
#          '결과': 10,
#          '만족': 10,
#          '자': 10,
#          '마냥': 10,
#          '밀어내기': 10,
#          '감미로운': 10,
#          '우울': 10,
#          '대하': 10,
#          '애': 10,
#          '그러길': 10,
#          '벽감': 10,
#          '순서': 10,
#          '심히': 10,
#          '청량한': 10,
#          '하늘': 10,
#          '아래': 10,
#          '있다는': 10,
#          '사실': 10,
#          '모로': 10,
#          '아쉬워서': 10,
#          '계속': 10,
#          '거듭': 10,
#          '만큼': 10,
#          '좋아해': 10,
#          '좀': 9,
#          '안전벨트': 9,
#          '출발': 9,
#          '담담하게': 7,
#          '이별': 7,
#          '갈래': 3,
#          '어떨까': 3,
#          '절': 1,
#          '크나큰': 1,
#          '밤그': 1,
#          '없음': 1,
#          '성큼': 1})

# %%
# Counter 객체를 DataFrame으로 변환
title_df = pd.DataFrame(title_counter.items(), columns=['단어', '빈도'])
# 결과 확인
title_df  # 처음 몇 개의 행을 출력하여 확인
# Out:
#        단어   빈도
# 0      사랑  197
# 1      자리   28
# 2       너  530
# 3      점철   27
# 4       밤  108
# ..    ...  ...
# 237  있었으면   11
# 238   좋겠어   11
# 239    순간   10
# 240    시작   10
# 241    팝송   10
#
# [242 rows x 2 columns]

# %%
# Counter 객체를 DataFrame으로 변환
explain_df = pd.DataFrame(explain_counter.items(), columns=['단어', '빈도'])
# 결과 확인
explain_df  # 처음 몇 개의 행을 출력하여 확인
# Out:
#         단어   빈도
# 0       우리  198
# 1      수많은   28
# 2       공간   56
# 3       그때   28
# 4       사랑  424
# ..     ...  ...
# 699     후회   13
# 700  없을거에요   13
# 701     트랙   13
# 702    순서도   13
# 703      맘   13
#
# [704 rows x 2 columns]
