# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('merge_clean_data')
data
# Out:
#                                               curHead    curArtist  \
# 0       드라이브 할 맛 나게 하는 트렌디하고 세련된 알앤비 국내힙합ㅣR&B Hip Hop  BIG Naughty
# 1       드라이브 할 맛 나게 하는 트렌디하고 세련된 알앤비 국내힙합ㅣR&B Hip Hop  BIG Naughty
# 2       드라이브 할 맛 나게 하는 트렌디하고 세련된 알앤비 국내힙합ㅣR&B Hip Hop  BIG Naughty
# 3       드라이브 할 맛 나게 하는 트렌디하고 세련된 알앤비 국내힙합ㅣR&B Hip Hop          박재범
# 4       드라이브 할 맛 나게 하는 트렌디하고 세련된 알앤비 국내힙합ㅣR&B Hip Hop          박재범
# ...                                               ...          ...
# 73570                          나만 알고 싶은 새벽감성 사클 노래 모음       Mabinc
# 73571                          나만 알고 싶은 새벽감성 사클 노래 모음       Mabinc
# 73572                          나만 알고 싶은 새벽감성 사클 노래 모음     YAYYOUNG
# 73573                          나만 알고 싶은 새벽감성 사클 노래 모음     YAYYOUNG
# 73574                          나만 알고 싶은 새벽감성 사클 노래 모음     YAYYOUNG
#
#                                            curTitle curColor  curPer  \
# 0                                       Vancouver      Black   56.89
# ...

# %%
# X_data는 curHead, curExplain, curPer, curColor, curObject
# y_data는 curArtist, curTitle
# curColor, curObject는 on-hot encoding 진행 (get_dummies 사용)

# %%
X_data = data[['curHead','curExplain','curPer','curColor','curObject']]
X_data
# Out:
#                                               curHead  \
# 0       드라이브 할 맛 나게 하는 트렌디하고 세련된 알앤비 국내힙합ㅣR&B Hip Hop
# 1       드라이브 할 맛 나게 하는 트렌디하고 세련된 알앤비 국내힙합ㅣR&B Hip Hop
# 2       드라이브 할 맛 나게 하는 트렌디하고 세련된 알앤비 국내힙합ㅣR&B Hip Hop
# 3       드라이브 할 맛 나게 하는 트렌디하고 세련된 알앤비 국내힙합ㅣR&B Hip Hop
# 4       드라이브 할 맛 나게 하는 트렌디하고 세련된 알앤비 국내힙합ㅣR&B Hip Hop
# ...                                               ...
# 73570                          나만 알고 싶은 새벽감성 사클 노래 모음
# 73571                          나만 알고 싶은 새벽감성 사클 노래 모음
# 73572                          나만 알고 싶은 새벽감성 사클 노래 모음
# 73573                          나만 알고 싶은 새벽감성 사클 노래 모음
# 73574                          나만 알고 싶은 새벽감성 사클 노래 모음
#
#                                               curExplain  curPer curColor  \
# 0                                                    NaN   56.89    Black
# 1                                                    NaN   36.46     Grey
# 2                                                    NaN    6.64     Pink
# ...

# %%
y_data = data[['curArtist','curTitle']]
y_data
# Out:
#          curArtist                                      curTitle
# 0      BIG Naughty                                   Vancouver
# 1      BIG Naughty                                   Vancouver
# 2      BIG Naughty                                   Vancouver
# 3              박재범                                    Like I Do
# 4              박재범                                    Like I Do
# ...            ...                                           ...
# 73570       Mabinc                            혼잣말 (feat. Ripley)
# 73571       Mabinc                            혼잣말 (feat. Ripley)
# 73572     YAYYOUNG  do you feel like you have no one to turn to?
# 73573     YAYYOUNG  do you feel like you have no one to turn to?
# 73574     YAYYOUNG  do you feel like you have no one to turn to?
#
# [73575 rows x 2 columns]
