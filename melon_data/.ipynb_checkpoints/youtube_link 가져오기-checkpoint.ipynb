# %%
## 데이터 분석 라이브러리
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import re
import time
import random
from tqdm.notebook import tqdm

## Selenium 관련 환경설정
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
caps = DesiredCapabilities.CHROME
caps["pageLoadStrategy"] = "none"

## bs 라이브러리
from bs4 import BeautifulSoup
import requests

# 페이지 로드 간소화 라이브러리
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# # webdriver options
options = wb.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
# options.add_argument('disable-dev-shm-usage')

# 이미지 로딩 비활성화
options.add_argument('--disable-images')
options.add_experimental_option("prefs", {
    'profile.managed_default_content_settings.images': 2,
    'profile.default_content_setting_values.media_stream_mic': 2,
    'profile.default_content_setting_values.media_stream_camera': 2,
    'profile.default_content_setting_values.geolocation': 2,
    'profile.default_content_setting_values.notifications': 2,
    'profile.default_content_setting_values.media_stream': 2,
    'profile.default_content_setting_values.automatic_downloads': 2,
    'profile.default_content_setting_values.autoplay': 2  # 자동재생 비활성화
})
options.add_argument('--blink-settings=imagesEnabled=false')
options.add_argument('--mute-audio')  # 소리 비활성화

# %%
df = pd.read_csv('melon_full_data.csv')
df.head(5)
# Out:
#                                             albumCov                   title  \
# 0  https://cdnimg.melon.co.kr/cm2/album/images/10...       Until I Found You
# 1  https://cdnimg.melon.co.kr/cm2/album/images/11...  IT'S YOU (feat. keshi)
# 2  https://cdnimg.melon.co.kr/cm2/album/images/10...              UNDERSTAND
# 3  https://cdnimg.melon.co.kr/cm2/album/images/10...                   stars
# 4  https://cdnimg.melon.co.kr/cm2/album/images/11...      Till There Was You
#
#           artistIdx                          albumIdx genreIdx  releasedAt  \
# 0   Stephen Sanchez                 Until I Found You       포크  2021.09.01
# 1               MAX                    LOVE IN STEREO      POP  2024.02.16
# 2             keshi  GABRIEL (Korean Special Edition)      POP  2022.03.25
# 3       Arash Buana                             stars      POP  2021.02.28
# 4  Imaginary Future                Till There Was You      POP  2023.05.02
#
#                                               lyrics  year
# 0  Georgia, Wrap me up in all your...\r\nI want y...  2021
# 1  Mm-hmm, no-oh, yeah, yeah\r\n\r\nIt's you\r\nL...  2024
# 2  Never thought that I'd find\r\nThat the one in...  2022
# 3                                                NaN  2021
# 4                                                NaN  2023

# %%
df['song'] = df['title'] + " " + df['artistIdx']
df
# Out:
#                                                 albumCov  \
# 0      https://cdnimg.melon.co.kr/cm2/album/images/10...
# 1      https://cdnimg.melon.co.kr/cm2/album/images/11...
# 2      https://cdnimg.melon.co.kr/cm2/album/images/10...
# 3      https://cdnimg.melon.co.kr/cm2/album/images/10...
# 4      https://cdnimg.melon.co.kr/cm2/album/images/11...
# ...                                                  ...
# 18647  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18648  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18649  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18650  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18651  https://cdnimg.melon.co.kr/cm2/album/images/10...
#
#                            title         artistIdx  \
# 0              Until I Found You   Stephen Sanchez
# 1         IT'S YOU (feat. keshi)               MAX
# 2                     UNDERSTAND             keshi
# 3                          stars       Arash Buana
# 4             Till There Was You  Imaginary Future
# ...                          ...               ...
# 18647                        찌질이               안재우
# 18648       She Said (with BIBI)             Crush
# 18649  Do It For Love (Feat. 죠지)             THAMA
# 18650           몇번째 (Song By 찬현)           KozyPop
# 18651   aura (Feat.샘김 (Sam Kim))                죠지
#
#                                albumIdx        genreIdx  releasedAt  \
# 0                     Until I Found You              포크  2021.09.01
# 1                        LOVE IN STEREO             POP  2024.02.16
# 2      GABRIEL (Korean Special Edition)             POP  2022.03.25
# 3                                 stars             POP  2021.02.28
# 4                    Till There Was You             POP  2023.05.02
# ...                                 ...             ...         ...
# 18647                               나쁜년  R&B/Soul, 인디음악  2021.01.05
# 18648                          with HER            랩/힙합  2020.10.20
# 18649                    Do It For Love        R&B/Soul  2020.06.24
# 18650                 Seoul Vibes Pt.15  R&B/Soul, 인디음악  2020.04.15
# 18651                             LEEEE        R&B/Soul  2019.10.03
#
#                                                   lyrics  year  \
# 0      Georgia, Wrap me up in all your...\r\nI want y...  2021
# 1      Mm-hmm, no-oh, yeah, yeah\r\n\r\nIt's you\r\nL...  2024
# 2      Never thought that I'd find\r\nThat the one in...  2022
# 3                                                    NaN  2021
# 4                                                    NaN  2023
# ...                                                  ...   ...
# 18647  그냥 그때 돌아서지 말걸\r\n라고 뱉으며 나 후회는\r\n한 백번 천번쯤에\r\n...  2021
# 18648  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...  2020
# 18649  아침햇살은 밝아\r\n텅 빈 하루를 살아 난\r\n나이는 적지 않아\r\n가끔씩 궁...  2020
# 18650  I love u 근데 나는 너무 아퍼\r\n내 맘을 아는 거면 너는 진짜 나뻐\r\...  2020
# 18651  you and me are different\r\nand i know it\r\n그...  2019
#
#                                       song
# 0        Until I Found You Stephen Sanchez
# 1               IT'S YOU (feat. keshi) MAX
# 2                         UNDERSTAND keshi
# 3                        stars Arash Buana
# 4      Till There Was You Imaginary Future
# ...                                    ...
# 18647                              찌질이 안재우
# 18648           She Said (with BIBI) Crush
# 18649      Do It For Love (Feat. 죠지) THAMA
# 18650             몇번째 (Song By 찬현) KozyPop
# 18651          aura (Feat.샘김 (Sam Kim)) 죠지
#
# [18652 rows x 9 columns]

# %%
song_list = df['song'].tolist()

# %%
song_list
# Out:
# ['Until I Found You Stephen Sanchez',
#  "IT'S YOU (feat. keshi) MAX",
#  'UNDERSTAND keshi',
#  'stars Arash Buana',
#  'Till There Was You Imaginary Future',
#  'Mozart : The Magic Flute K.620 Act.II - Queen Of The Night Aria \'Der Holle Rache\' (모차르트 : 마술 피리 - 2막. 밤의 여왕의 아리아) (From "Amadeus") Bulgarian National Radio Symphony Orchestra, John Landor, Rachel Rosales',
#  'What We Found Jesse Barrera, Nieman, Melissa Polinar',
#  'Real Love Still Exists 헨리 (HENRY), Yuna',
#  'Old Love (Stripped) yuji, putri dahlia',
#  'Letters (Acoustic) Maximillian',
#  'I Want You Stephen Sanchez',
#  'Butterflies (Acoustic) Abe Parker',
#  'EDIE CELINE (Stripped Version) MAX',
#  'Ripples (Acoustic) Maximillian',
#  'still that kid (deep down) Yaeow',
#  'favorite lesson Yaeow',
#  'This Is How It Feels d4vd, Laufey',
#  'The Green (Acoustic ver.) Chris James',
#  'Stuck Here Without You Yaeow',
#  'What I Feel Is Love Etham',
#  'all i need (the distance song) Avery Lynch',
#  'Everyone Adores You (quiet) Matt Maltese',
#  'Starlight 92914',
#  'la la la that’s how it goes (dream edit) HONNE',
#  'Tin Lover The Paper Kites',
#  'free love (dream edit) HONNE',
#  'Love Is (Intro) Gogang (고갱)',
#  'gone gone gone (dream edit) HONNE',
#  'million little reasons Oscar Lang',
#  'Okinawa (오키나와) 92914',
#  'Remember Sam Ock',
#  'one way to tokyo (dream edit) HONNE',
#  'In The Wee Small Hours Of The Morning Joey Stamper',
#  'do you want my love? SOLOMON',
#  'silent Sam Ock',
#  'When You Wash Your Hair Matt Maltese',
#  'another guy Finding Hope',
#  'Your Night Is My Dream Gogang (고갱)',
#  'For All You Give (Feat. Lucy Rose) The Paper Kites',
#  'yellow lights Finding Hope',
#  'to the moon & back Finding Hope',
#  'When The World Stopped Moving Lizzy McAlpine',
#  "I Don't Know You At All Lizzy McAlpine",
#  'Angelina Lizzy McAlpine',
#  'Wanderlust ELOISE',
#  'My Little Island Lyn Lapid',
#  'In Agreement Lizzy McAlpine',
#  '...What Are We? Lizzy McAlpine',
#  'When She Loved Me Lyn Lapid',
#  'Stupid Lizzy McAlpine',
#  'Not Alone Siv Jakobsen',
#  'any picture with you Joie Tan',
#  'Jack Rabbit (Live) King Louie & Baby James',
#  'Exhausted chloe moriondo',
#  'In What World Lizzy McAlpine',
#  'temporary nothing (revisited) mxmtoon',
#  'Bubble Gum Clairo',
#  "A Soulmate Who Wasn't Meant to Be Jess Benko",
#  'goodbye and godspeed Sarah Kang',
#  'now i know Sarah Kang',
#  'stars Arash Buana',
#  'Spring Ed Sheeran',
#  'Blue Elina',
#  'mountain kiyu',
#  'Nothing More Than That The Paper Kites',
#  "i've always loved you Arash Buana",
#  'Another Round Elina',
#  'Only One The Paper Kites',
#  'Clear Eyes Mokita',
#  'How Elina',
#  "we'll be okay, for today (Feat. Anya Taroreh) Arash Buana",
#  'Tin Lover The Paper Kites',
#  'Blossom Porter Robinson',
#  "Life We've Built Portair, Emily James",
#  "I'd Like to Know You Walker",
#  'We Good Jesse Gold',
#  'Here I Am Again Tommy Walker, The C.A. Worship Band',
#  "I'll Be Right Here Walker",
#  'This Bag Mac Ayres, Jack Dine',
#  'Good Man Walker',
#  'that shit is on you (Explicit Ver.) Walker',
#  'Calypso Jackson Lundy',
#  'Daisy 체이스 (Chase)',
#  'Waiting on a Friend Walker',
#  "Won't Be Here Long Walker",
#  'Walk Talk 오닐 (ONiLL)',
#  'Beethoven: Symphony No. 9 in D Minor, Op. 125: 4f. Allegro energico (Live - Remastered 2019) Leonard Bernstein, June Anderson, Sarah Walker, Klaus Konig, Jan-Hendrik Rootering, Members of the Staatskapelle Dresden',
#  "It's Not (Her Eyes) Walker",
#  'Surf Mac Miller',
#  'Without You Walker, Noe Mina',
#  'Unknown (Feat. Conor Albert) Alice Auer',
#  'Not an Apology Walker',
#  'Just You and I Tom Walker',
#  'Closer The Silhouettes Project, Elisa Imperilee, Whoeva?',
#  'Mr & Mrs Brown Luisa Sobral',
#  "Poppin' Angela Moyra",
#  'Nothing More Gabe Bondoc',
#  "It's Love (Feat. Marle Thomson) Anthony Lazaro",
#  'Treat Me Better Rachael & Vilray',
#  'Do Friends Fall in Love? Rachael & Vilray',
#  'Here We Go Again / Fanboi Ardhito Pramono',
#  'Hummingbird (Feat. Marle Thomson) Anthony Lazaro',
#  "Diggin' Me Martin Sexton",
#  'Loved You First Gabe Bondoc',
#  'Two Sleepy People Carsie Blanton',
#  'Moonlight (Feat. Marle Thomson) Anthony Lazaro',
#  'Stronger Than Gabe Bondoc',
#  'Happy Talk Diana Panton',
#  'Do You Want to Know a Secret Mathilda Homer',
#  'catching feelings 4 u Jason LaPierre',
#  "Let's Make Love on This Plane (Full Band Version) [Bonus Track] Rachael & Vilray",
#  'Any Little Time Rachael & Vilray',
#  'Sunny Days Ginne Marker',
#  '925 Ardhito Pramono',
#  'Goodnight My Love Rachael & Vilray',
#  'Hate is the Basis (of Love) Rachael & Vilray',
#  'find love (Feat. THAMA) Jason Lee (제이슨 리)',
#  'wherever u r (ft. V of BTS) UMI, V',
#  'dinner in bed Gareth.T',
#  'Slow Dance In The Morning Jesse Gold',
#  'lavender (Feat. Pink Sweat$) JVKE',
#  'Flower (Piano Version) Johnny Stimson',
#  'unrequited SOLOMON',
#  'I LOVE YOU (feat. JUNNY, Sam Ock) dress',
#  'HEY THAMA',
#  'Hey Billie 92914',
#  'Be So Cruel (Stripped) ASTN',
#  'Officially Missing You Joseph Solomon',
#  'How Soon (Stripped Version) ASTN',
#  'WANDERLUST Paul Partohap',
#  'I Feel Love THAMA',
#  'Fall 4 U Taiyo Ky',
#  'u & i Anthony Russo',
#  'Turn Your Lights Down Low Joseph Solomon',
#  "The 1 (Corey's Version) Corey Harper",
#  'You got me! (Acoustic) 레몬시티(Lemon City)',
#  'Lucky Day Michael Carreon',
#  'melancholy song MIKA(米卡)',
#  'Rainy Day Theme Devin Kennedy',
#  'My Love Mine All Mine Mitski',
#  'Keep Me Novo Amor',
#  'do you want my love? SOLOMON',
#  'Tin Lover The Paper Kites',
#  'John Wayne Cigarettes After Sex',
#  'million little reasons Oscar Lang',
#  'For All You Give (Feat. Lucy Rose) The Paper Kites',
#  'Until I Found You Stephen Sanchez',
#  'Everyone Adores You (quiet) Matt Maltese',
#  'Sunsetz Cigarettes After Sex',
#  'No Fun Novo Amor, Gia Margaret',
#  'you. Oscar Lang',
#  'Still Feel It All MARO',
#  'In Tall Buildings Matt Maltese',
#  'Less and Less Matt Maltese',
#  'No Fun Novo Amor, Gia Margaret',
#  'Keep On Loving You Cigarettes After Sex',
#  'You Deserve an Oscar (quiet) Matt Maltese',
#  'Loving & Losing Delaney Bailey',
#  "Even If It's A Lie (Demo) Matt Maltese",
#  'Bubblegum Cigarettes After Sex',
#  'Krakow (unsung) Matt Maltese',
#  'In The Morning Rocco',
#  'NO THING John OFA Rhee',
#  'Timeless Sam Ock',
#  'Sunny Rocco',
#  'Love Feels Like Johnny Stimson',
#  'Orange Splash (feat. 진동욱) 정바스 (J.BASS)',
#  'All for You (Feat. Theo Juarez) Micah Edwards',
#  'Bitterlove Ardhito Pramono',
#  'Soulmate Johnny Stimson, Jeremy Passion',
#  'I Wonder M.I.L.K.',
#  'The Answer Gabe Bondoc, Patrick Hizon',
#  'One In A Million (Feat. Stefani Kimber) Jesse Gold',
#  'Drunk Texting (Feat. Kai Takahashi) Max Jenmana',
#  "If We'd Never Met Gabe Bondoc",
#  'Dance With You Tonight Laufey',
#  'cheeze (Feat. Andrew Kang) Sarah Kang',
#  'Sentimental Mood 와사비호텔 (wasabi hotel)',
#  'Mariposa Peach Tree Rascals',
#  'Sunkissed (again&again Remix) Khai Dreams',
#  'SECRETS JVKE',
#  'March, April, May Wouter Hamel',
#  'Yards / Gardens Kate Bollinger',
#  'Thinking Of Me Johnny Orlando',
#  'EDIE CELINE (Stripped Version) MAX',
#  'Forever Was Never Enough Peder Elias',
#  'Sick of You Suriel Hess',
#  'Drown Boy In Space',
#  'Young (Acoustic) RYMAN',
#  'Castle Rock Nieman',
#  'Lifetime Faime',
#  'be gentle with me Yaeow',
#  'Right One Wrong Time sunshine blvd.',
#  'superglue (stripped) joan',
#  'The Longest Goodbye (Live in Topanga) Rosie Darling',
#  'forget me (demo) Valley',
#  'favorite lesson Yaeow',
#  'I Wish Faime',
#  'Love Feels Like Johnny Stimson',
#  'Everyday Feels Like Sunday Jesse Barrera, Albert Posis',
#  'Maybe We Could Be a Thing Jesse Barrera, Michael Carreon, Albert Posis',
#  'Hold On Tight Jesse Barrera, Albert Posis',
#  'Serendipity (Anniversary Edition) Albert Posis',
#  'The Answer Gabe Bondoc, Patrick Hizon',
#  'You Can Do It Johnny Stimson',
#  'Cheeky Albert Posis, Patrick Hizon',
#  'Everlasting Albert Posis',
#  'Deja Vu Jesse Barrera, Patrick Hizon',
#  'This Time Michael Carreon',
#  'Still The One Jesse Barrera',
#  'Soulmate Johnny Stimson, Jeremy Passion',
#  'Sweatshirt Patrick Hizon, EJEAN',
#  'Back to You Albert Posis',
#  'Hello Albert Posis',
#  "You Ain't Gotta Jesse Barrera, Albert Posis",
#  'Lucky Day Michael Carreon',
#  'Butterflies Johnny Stimson',
#  'Hail Mary Jesse Barrera, Tim Atlas',
#  'Like I Do Jesse Barrera, Melissa Polinar',
#  'Unaware Jesse Barrera, Albert Posis',
#  'Sway Jesse Barrera, Gabe Bondoc',
#  'Rest Assured Jeff Bernat, Albert Posis, Jesse Barrera, PRVDNT',
#  'CHIVALRY IS DEAD Jesse Barrera, Albert Posis',
#  '우리들의 아픔을 잃길 바랐는데 겸 (GYE0M)',
#  'Meant to be 백예린 (Yerin Baek)',
#  'Love is a Flower Colde (콜드)',
#  'Greed Jiwoo',
#  'Aston Jiwoo',
#  'can i b u 백예린 (Yerin Baek)',
#  '상실 Colde (콜드)',
#  '터널 Colde (콜드)',
#  'Sweetbitter 리오 (RIO)',
#  'Somehow 오존 (O3ohn)',
#  '고요 NUZ (누즈)',
#  '그러니까... 10CM',
#  'Endless Love Colde (콜드)',
#  'Thoms Piano 오존 (O3ohn)',
#  '널 사랑하지 않는 날이 올까 coldnight',
#  '우린 마를 리 없었지 겸 (GYE0M)',
#  '느릿느릿 지는 해를 바라보자 The Poles (더 폴스)',
#  '흠 SOLE (쏠)',
#  'When Can We Be Bruno Major',
#  'Trajectories Bruno Major',
#  'Blue Room Chet Baker',
#  "You're Mine, You! Chet Baker",
#  'one way to tokyo (dream edit) HONNE',
#  'Starlight 92914',
#  'do you want my love? SOLOMON',
#  "Places We Won't Walk Bruno Major",
#  "Regent's Park Bruno Major",
#  'la la la that’s how it goes (dream edit) HONNE',
#  'Sweet Sue, Just You Chet Baker',
#  'silent Sam Ock',
#  'Letter Milena (밀레나)',
#  "St Mary's Terrace Bruno Major",
#  'Everyone Adores You (quiet) Matt Maltese',
#  'Love Is (Intro) Gogang (고갱)',
#  'Your Night Is My Dream Gogang (고갱)',
#  'As Beautiful As You Will Post',
#  'Song on the Beach Arcade Fire, Owen Pallett',
#  'come into my arms November Ultra',
#  "You're The Cream In My Coffee (영화 홀드 에브리씽) Nat King Cole Trio",
#  'On The Sunny Side Of The Street (영화 신부의 아버지 2) Nat King Cole Trio',
#  "Say It Isn't So Dick Haymes",
#  'Say it With Music Dick Haymes',
#  "If You Can't Smile And Say Yes Nat King Cole Trio",
#  "After You Get What You Want, You Don'T Want It Nat King Cole",
#  'Bring Another Drink Nat King Cole Trio',
#  "Youll Never Know (From 'Hello Frisco - Hello') Dick Haymes & The Song Spinners",
#  'Lady Of The Evening Dick Haymes',
#  'Cuckoo In The Clock (2013 - Remaster) Bobby Troup',
#  'Frim Fram Sauce Diana Krall',
#  'Dream A Little Dream Of Me Nat King Cole',
#  'Soft Lights And Sweet Music Dick Haymes',
#  'Night Falls Again (late 1946) Stuff Smith',
#  "I'D Love To Make Love To You Nat King Cole",
#  "I Just Can't See For Lookin' Nat King Cole",
#  "I'm in the Mood for Love Nat King Cole Trio",
#  'Go Fats Navarro, Don Lanphere',
#  'The Song Is Ended Dick Haymes',
#  "What Can I Say After I Say I'M Sorry? Nat King Cole",
#  '(Get Your Kicks on) Route 66 김주환',
#  'When I Take My Sugar To Tea Nat King Cole',
#  "Darlin' It's Just Like a Dream (Feat. Rabon Tarrant) Jack McVea",
#  'My Blue Heaven Gene Austin, Nat Shilkret Orchestra',
#  "Alfred: You Don'T Learn That In School The Nat 'King' Cole Trio",
#  "I'm a Shy Guy Nat King Cole Trio",
#  'Too Marvelous For Words (영화 카페 소사이어티) Nat King Cole Trio',
#  'Beautiful Moons Ago Nat King Cole Trio',
#  'Straighten Up And Fly Right (비디오 게임 마피아 2) Nat King Cole Trio',
#  "Atkinson, Oliver: But She'S My Buddy'S Chick The Nat 'King' Cole Trio",
#  'Moonglow Erroll Garner',
#  'The Christmas Waltz Frank Sinatra',
#  "I'Ll Be Home For Christmas Frank Sinatra",
#  'A Winter Romance Dean Martin',
#  'White Christmas Dean Martin',
#  'Let It Snow (2024 Remastered) Dean Martin',
#  'There Is No Christmas Like a Home Christmas Perry Como',
#  'Silver Bells Perry Como',
#  'Here We Come a-Caroling / We Wish You a Merry Christmas Perry Como',
#  "You're All I Want for Christmasb Bing Crosby & The Ken Kane Singers",
#  'White Christmas (Single Version) Louis Armstrong, Gordon Jenkins & His Orchestra',
#  "It's Christmas Time Again Peggy Lee",
#  'Silver Bells (영화 나홀로 집에2) Dean Martin',
#  'The Christmas Song (영화 러브 어페어) Perry Como',
#  'Rudolph, The Red-Nosed Reindeer (만화영화 루돌프 사슴코) Dean Martin',
#  'The Christmas Waltz Peggy Lee',
#  'The Things We Did Last Summer Dean Martin',
#  'The Christmas Spell Peggy Lee',
#  'Winter Wonderland (LOUALLDAY Lofi Flip) Bing Crosby',
#  "I'd Like You For Christmas (Remastered 2004) Julie London",
#  'O Holy Night Nat King Cole',
#  'Ole! Santa Dinah Washington',
#  'Winter Wonderland (Single Version) Louis Armstrong, Gordon Jenkins & His Orchestra',
#  "What Are You Doing New Year's Eve? Kay Kyser",
#  "Santa Claus Is Comin' to Town (1959 Version) Perry Como",
#  'I Need You Christmas Jonas Brothers',
#  'The First Noel Giveon',
#  'Have Yourself a Merry Little Christmas Sarah Kang, Sam Ock',
#  'Last Christmas ASTN',
#  'Winter Wonderland Albert Posis',
#  'The Christmas Song Johnny Stimson',
#  'Falling (feat. Milena (밀레나)) HYESUNG (혜성)',
#  'Have Yourself a Merry Little Christmas Juliana Chahayed, Hubie',
#  'Christmas Time Is Here Daniela Andrade',
#  'THE CHRISTMAS SONG (CHESTNUTS ROASTING) Joseph Solomon',
#  'Christmas Dreaming Laufey',
#  'Mr. Snowman Sarah Kang, Sam Ock',
#  'Little Christmas keepitinside',
#  'Santa Baby Daniela Andrade',
#  'No Santa MEENOI',
#  'Snowed In Conor Matthews',
#  'The Christmas Song Juliana Chahayed, Hubie',
#  'November song 백예린 (Yerin Baek)',
#  'Winter Wonderland Laufey',
#  "Chipmunk Song (Christmas Don't Be Late) Juliana Chahayed, Hubie",
#  'Have Yourself A Merry Little Christmas Jeff Bernat',
#  'All I Want for Christmas Is You Juliana Chahayed, Hubie',
#  'Christmas Starts Tonight grentperez',
#  'Alone on Christmas Eve Mabes',
#  'Snow Day Caitlyn Smith',
#  'White Christmas Jeff Bernat',
#  'Sleigh Ride Jennifer Chung',
#  'Nobody Home Johnny Hartman',
#  "It's Easy To Remember Johnny Hartman, Erroll Garner",
#  'For All We Know 김주환',
#  'Frim Fram Sauce Diana Krall',
#  'Moonstruck Al Bowlly',
#  'I Let a Song Go out of My Heart Johnny Hartman',
#  'When Your Lover Has Gone (Remastered 2016) Johnny Hartman',
#  '(I Love You) For Sentimental Reasons (Remastered 2003) Nat King Cole Trio',
#  "I'm Confessin' (That I Love You) Dean Martin",
#  'What is There to Say? (Remastered 2016) Johnny Hartman',
#  "I Tho't You Ought To Know Nat King Cole",
#  "You'Re Nobody 'Til Somebody Loves You Nat King Cole",
#  'Moonlight in Vermont (Remastered 2016) Johnny Hartman',
#  'Remember Johnny Hartman',
#  'Solitude Billie Holiday',
#  "I'll Be Seeing You Billie Holiday",
#  'How Does It Feel? - Original Nat King Cole Trio',
#  "I'm Thru With Love (Remastered) Nat King Cole Trio",
#  "I'll Never Smile Again (영화 굿 모닝 베트남) Erroll Garner",
#  "What Can I Say After I Say I'M Sorry? Nat King Cole",
#  "They Didn't Believe Me Johnny Hartman",
#  'I\'ve Got the World On a String (From "Cotton Club Parade") The Nat King Cole Trio',
#  'You Call It Madness (But I Call It Love) Nat King Cole Trio',
#  'Christmas miracle Luca minor',
#  'I Think It Must Be Christmas Bruno Major',
#  "I'll Be Home for Christmas Mokita",
#  'Christmas song Luca minor',
#  "What Are You Doing New Year's Eve? Anthony Lazaro, Anna Elizabeth Laube",
#  'The Christmas Song Anson Seabra',
#  'My Fire Sam Ock',
#  'I Love you for sentimental reasons Horim (호림)',
#  "Winter's Cold (Feat. Sam Ock) Jae Jin",
#  'Keep Me Warm Sam Ock',
#  'Remember Sam Ock',
#  'Better Than Snow Norah Jones, Laufey',
#  'Corner Booth Jae Jin, Sam Ock',
#  'Winter waltz FRANKIE',
#  'Christmas Time Is Here Daniela Andrade',
#  'Morning After Night Sarah Kang, Sam Ock',
#  'silent Sam Ock',
#  'Warm wishes on christmas Beer',
#  'The Christmas Waltz Laufey',
#  "New Year's Eve Ardhito Pramono",
#  "It's Beginning To Look A Lot Like Christmas Matthew Ifield",
#  'Winter Wonderland Matthew Ifield',
#  "I'll Be Home for Christmas Michael Buble",
#  'Christmas Dreaming Laufey',
#  'Have Yourself A Merry Little Christmas Matthew Ifield',
#  'Holly Jolly Christmas Matthew Ifield',
#  'The Christmas Waltz Laufey',
#  'Santa Claus Is Coming to Town Michael Buble',
#  'The Christmas Song Matthew Ifield',
#  'White Christmas Matthew Ifield',
#  'Winter Wonderland Laufey',
#  'Santa Baby Lauren Spencer-Smith',
#  'Have Yourself A Merry Little Christmas Norah Jones, Laufey',
#  "It's Beginning to Look a Lot like Christmas Michael Buble",
#  'Holly Jolly Christmas Michael Buble',
#  'Winter Weather (Feat. Reg Schwager, Don Thompson) Diana Panton',
#  'Sleigh Ride Jennifer Chung',
#  'The Christmas Song (Chestnuts Roasting on an Open Fire) Michael Buble',
#  'Santa Baby Michael Buble',
#  'Warm In December Samara Joy',
#  'White Christmas Ella Fitzgerald',
#  "Season's Taste Sam Ock",
#  'Ever Celebrate Sam Ock',
#  'Silver Bells (feat. Naturally 7) Michael Buble',
#  'Jupiter Matt Maltese',
#  'On My Mind Tonight Vividry',
#  'Made Up My Mind Vividry',
#  'Who Needs Words YOUNG GUN SILVER FOX',
#  'The Other Half Victor Lundberg',
#  'Pass Me Vividry',
#  'High Time Vividry',
#  'THIS IS THE DAY Mamas Gun',
#  'Good Times Are Coming L.M. Styles',
#  'A Million Signs Vividry',
#  'Looking for a Fire (Instrumental Version) Vividry',
#  'Go Through It [At PizzaExpress Live] Mamas Gun',
#  'Wish I Could (Feat. Andy Delos Santos) Victor Lundberg',
#  'Pots Of Gold (2016 현대 소나타 광고 삽입곡) Mamas Gun',
#  'My World Vividry',
#  'One on One (Feat. Astyn Turr) Wildson',
#  'Something Keeps Calling (Feat. Rob Bacon) Raphael Saadiq',
#  "Can't Hold It in Anymore Vividry",
#  'You Make My Life a Better Place Mamas Gun',
#  'Come Out Vividry',
#  'Good Love Mamas Gun',
#  'I Ran All the Way Home Sarah Vaughan',
#  'Time to Go Sarah Vaughan',
#  "I Guess I'll Have to Dream the Rest (Feat. Thepied Pipers) Frank Sinatra & Tommy Dorsey",
#  'In The Moon Mist (1992 Digital Remaster) Pied Pipers With Jo Stafford',
#  "That's My Desire (Remastered 2000) Martha Tilton",
#  'Vanity Sarah Vaughan',
#  "It's Been A Long, Long Time (Feat. Bing Crosby) Les Paul",
#  'Deep In A Dream - Original Mono Connee Boswell',
#  'Prelude to a Kiss Billie Holiday',
#  'Once In A While Sarah Vaughan',
#  'What Is There to Say Chris Connor',
#  'Everything Depends On You Mildred Bailey',
#  'Manhattan Lee Wiley, Bobby Hackett, Joe Bushkin and His Swining Strings',
#  'You Started Something Daryl Sherman & John Cocuzzi',
#  'Willow Weep For Me (Live) Sarah Vaughan',
#  'Everytime (Original Mix) Chris Connor',
#  'How Am I to Know (Original Mix) Ava Gardner',
#  'Born to Be Blue Mildred Bailey',
#  'On The Sunny Side Of The Street (영화 신부의 아버지 2) Nat King Cole Trio',
#  "Can't We Be Friends Mildred Bailey",
#  'I Want You Stephen Sanchez',
#  'Love Life Stephen Sanchez',
#  'Until I Found You Stephen Sanchez',
#  "IT'S YOU (feat. keshi) MAX",
#  'Be So Cruel ASTN',
#  'Butterflies Abe Parker',
#  'Remember Sam Ock',
#  'The Pool Stephen Sanchez',
#  'Because Of You Stephen Sanchez',
#  'Everyone Adores You (quiet) Matt Maltese',
#  'Until I Found You Stephen Sanchez',
#  'UNDERSTAND keshi',
#  'do you want my love? SOLOMON',
#  'Keep Me Novo Amor',
#  'million little reasons Oscar Lang',
#  'Kayla Stephen Sanchez',
#  'Tin Lover The Paper Kites',
#  'In The Wee Small Hours Of The Morning Joey Stamper',
#  'This Is How It Feels d4vd, Laufey',
#  'When You Wash Your Hair Matt Maltese',
#  'Castle Rock Nieman',
#  'Real Thing (feat. Tori Kelly) Pink Sweat$',
#  'Jupiter To Mars Rocco',
#  "don't let me forget you love me shy martin",
#  'silent Sam Ock',
#  'A Forgotten Place Creative Self',
#  'Last Train Home Creative Self',
#  'Moonlight and Rain Kalaido',
#  'fountain leavv',
#  'Beyond the Stars I (Original Mix) Kainbeats',
#  "Don't Leave Me This Way Tomppabeats",
#  'Lilac Kainbeats',
#  'pure imagination Bassti',
#  'Stars and Chimneys Kalaido',
#  'Going Nowhere Creative Self',
#  'See You Later Creative Self',
#  'Formless Gift Creative Self',
#  'Full Bloom Creative Self',
#  'Letters (Acoustic) Maximillian',
#  'Gina Pink Sweat$',
#  'This Is How It Feels d4vd, Laufey',
#  'UNDERSTAND keshi',
#  'favorite lesson Yaeow',
#  "people don't change (demo) Kamal.",
#  'this is how you fall in love Jeremy Zucker, Chelsea Cutler',
#  'burn out (Acoustic) SOLOMON',
#  'forgettable Yaeow',
#  'Mozart : The Magic Flute K.620 Act.II - Queen Of The Night Aria \'Der Holle Rache\' (모차르트 : 마술 피리 - 2막. 밤의 여왕의 아리아) (From "Amadeus") Bulgarian National Radio Symphony Orchestra, John Landor, Rachel Rosales',
#  'to my future love Finding Hope',
#  'okay Avery Lynch, ROSIE',
#  'Dngrs Interlude Sylo',
#  'Up In The Sky Emilee Moore',
#  'always keshi',
#  'Pink cheeks eldon',
#  "Hittin' Different Hadji Gaviota",
#  'Thank You JUNNY (주니)',
#  'Workflow (Feat. Dumbfoundead) Jeff Bernat',
#  '925 Ardhito Pramono',
#  'Back for More Michael McGehee',
#  'Rest Assured Jeff Bernat, Albert Posis, Jesse Barrera, PRVDNT',
#  'Beautiful Life (feat. sky) Jeremy Passion',
#  'As Long As You Wait For Me Jeremy Passion',
#  "This Ain't The Way (Feat. Tori Kelly) Jeremy Passion",
#  'Nothing Jeremy Passion',
#  'The Math Gabe Bondoc',
#  'Why Do I Still? (Unplugged) (feat. May Angeles) Nieman',
#  'Oh Vienna Jeremy Passion',
#  'Anywhere Anything Gabe Bondoc',
#  "I Don't Care Jeremy Passion",
#  'Meant to Be Melissa Polinar, Jeremy Passion, Gabe Bondoc',
#  'In the End Melissa Polinar, Jeremy Passion, Gabe Bondoc',
#  'You Should Know Jeremy Passion',
#  'Change (Interlude) Jeremy Passion',
#  'Treat You Good Gabe Bondoc',
#  'My Plan (2019 ver.) Gabe Bondoc',
#  'By Example Jeremy Passion',
#  "Jacob's Blues Gabe Bondoc",
#  'Paper Airplane (Feat. Melissa Polinar) Jeremy Passion',
#  'Better Jeremy Passion',
#  'Hello Albert Posis',
#  'Good Thing Good Time Gabe Bondoc',
#  'Pretty Girl Hi Reimagined UMI',
#  'Slow Dance In The Morning Jesse Gold',
#  'Sunday Devin Kennedy',
#  'Fine Wine Devin Kennedy',
#  'found. Seiji Oda',
#  'rain golf BROCKBEATS',
#  'Walk In The Park Devin Kennedy',
#  'Movie Popcorn Matthew Ifield',
#  'Blink (Feat. Akurei) The Nicholas',
#  'Maybe? RADI',
#  "Writer's Block Dylan Bernard",
#  'Like I Do Matthew Ifield',
#  'violet skies Colette Lush',
#  'goodnight kiss (in December) Rahmania Astrini',
#  '이런 슬픈 노래 지소울 (GSoul)',
#  'Feelings Matthew Ifield',
#  'If (Original Movie Soundtrack from "Yung Libro Sa Napanood Ko") mrld',
#  'Right One Wrong Time sunshine blvd.',
#  'Dngrs Interlude Sylo',
#  'Let Me Know LANY',
#  'cowboy in LA LANY',
#  'you! LANY',
#  'sharing you LANY',
#  '13 LANY',
#  'Pink Skies LANY',
#  'Mean It Lauv, LANY',
#  "I Don't Wanna Love You Anymore LANY",
#  "when you're drunk LANY",
#  "heart won't let me LANY",
#  'anything 4 u LANY',
#  'nobody else LANY',
#  'dna LANY',
#  'remember that LANY',
#  'up to me LANY',
#  "’til i don't LANY",
#  'one minute left to live LANY',
#  'paper LANY',
#  'if this is the last time LANY',
#  '(what i wish just one person would say to me) LANY',
#  'Thru These Tears LANY',
#  'Thick And Thin LANY',
#  'the older you get, the less you cry LANY',
#  'sad (stripped) LANY',
#  'Current Location LANY',
#  "Valentine's Day LANY",
#  'dancing in the kitchen LANY',
#  'It Was Love LANY',
#  'Change Ya Mind Mac Ayres',
#  'Woman HONNE',
#  'Keep On Loving You Cigarettes After Sex',
#  '13 LANY',
#  'Go Downstairs to the Blue Moon, Buy Some Fried Chicken Bubble Tea and Cigarettes',
#  'seasons wave to earth',
#  'You Might Be Sleeping (Feat. Clairo) JAKOB',
#  'This Is How It Feels d4vd, Laufey',
#  'Nothing Compares Devin Kennedy',
#  '50 proof eaJ',
#  'Sincerely, eaJ',
#  'A Starry Night in Apollo Bay RINI',
#  'ANGEL keshi',
#  'If i am without u Yaeow',
#  'la trains eaJ',
#  'Real Love Still Exists 헨리 (HENRY), Yuna',
#  'phases (Acoustic) SOLOMON',
#  'another guy Finding Hope',
#  'favorite lesson Yaeow',
#  '5g brakence',
#  'Ribbons Ryan Beatty',
#  'yellow lights Finding Hope',
#  'Perfume Mehro',
#  'Okay Finding Hope',
#  "i'm sorry Joshua Bassett",
#  'a song for when you fall in love Yaeow',
#  "Valentine's Day Finding Hope",
#  'time moves slow Public Library Commute',
#  'Tin Lover The Paper Kites',
#  'million little reasons Oscar Lang',
#  "Let's Stay Together Joesef",
#  'Everyone Adores You (quiet) Matt Maltese',
#  'For All You Give (Feat. Lucy Rose) The Paper Kites',
#  'Fish Billie Marten',
#  'When You Wash Your Hair Matt Maltese',
#  'Paris New West',
#  'Untitled 2 (Live) Puma Blue',
#  'La Vie En Rose Emily Watts',
#  'Mystery (quiet) Matt Maltese',
#  'Dialing Drunk Ethan Gruska',
#  'Hindenburg Lover Anson Seabra',
#  'True Love Will Find You In The End SOMEONE, Benjamin Longman',
#  'Teeth Billie Marten',
#  'Does it Ever Cross Your Mind The Paper Kites',
#  'Early Morning Still Benjamin Torrens',
#  'Want Me Puma Blue',
#  'Gravity Anthony Lazaro',
#  'A Gathering On 57th The Paper Kites',
#  'Loving You Girl (Feat. Hkeem) Peder Elias',
#  'I Like Me Better Lauv',
#  'Midnight Flight Conor Matthews',
#  'Good, but not together Valley',
#  'Narcissist (Feat. The 1975) No Rome',
#  'Signs Ethan Dufault',
#  'what are we Virginia To Vegas',
#  'ROSS AND RACHEL Jake Miller',
#  "All 4 Nothing (I'm So In Love) Lauv",
#  'Forever Right Now (Acoustic) Conor Matthews',
#  'Older Conor Matthews',
#  'Mean It Lauv, LANY',
#  'dna LANY',
#  'the movies Nightly',
#  'View Ethan Dufault',
#  'Oh shit…are we in love? Valley',
#  "i'm so tired... Lauv, Troye Sivan",
#  'Not About You (ENG Ver.) JUNNY (주니)',
#  'ex i never had LANY',
#  'Sunday Breakfast Anthony Lazaro',
#  'Ten Years from Now (Feat. Marle Thomson) Anthony Lazaro',
#  'Goodnight My Love Rachael & Vilray',
#  "Let's Make Love on This Plane (Full Band Version) [Bonus Track] Rachael & Vilray",
#  "It's Love (Feat. Marle Thomson) Anthony Lazaro",
#  'Moonlight (Feat. Marle Thomson) Anthony Lazaro',
#  'Love to Keep Me Warm Laufey, dodie',
#  'Do You Want to Know a Secret Mathilda Homer',
#  "'S Wonderful (Bonus Track) Kat Edmonson",
#  'Hummingbird (Feat. Marle Thomson) Anthony Lazaro',
#  'From The Start Laufey',
#  'Postcards from Rome Anthony Lazaro',
#  'Do Friends Fall in Love? Rachael & Vilray',
#  'Treat Me Better Rachael & Vilray',
#  'Call It Love (Feat. Marle Thomson) Anthony Lazaro',
#  'Like the Movies Laufey',
#  'Two Sleepy People Carsie Blanton',
#  'Lover for Hire Anthony Lazaro',
#  'Mr & Mrs Brown Luisa Sobral',
#  'I Wish You Love Laufey',
#  'Shivers (Ed Sheeran Cover) Anthony Lazaro',
#  "The Day I'm In Love Anthony Lazaro",
#  'Any Little Time Rachael & Vilray',
#  'Why Do I? Rachael & Vilray',
#  'Hey! Anthony Lazaro',
#  'Is a Good Man Real? Rachael & Vilray',
#  'Grow Old Together Anthony Lazaro',
#  'The Phone Ring Anthony Lazaro',
#  'Just Two Rachael & Vilray',
#  'It Might as Well Be Spring (Feat. Kyle Pogline) Caity Gyorgy',
#  'Chocolate Ice Cream (Feat. Marle Thomson) Anthony Lazaro',
#  'Letter Milena (밀레나)',
#  'Love Is (Intro) Gogang (고갱)',
#  'silent Sam Ock',
#  'Blossom Porter Robinson',
#  'Your Night Is My Dream Gogang (고갱)',
#  'stars Arash Buana',
#  'Starlight 92914',
#  'Remember Sam Ock',
#  'one way to tokyo HONNE',
#  'yellow lights Finding Hope',
#  "IT'S YOU (feat. keshi) [Stripped Version] MAX",
#  'Be So Cruel (Stripped) ASTN',
#  'How Soon (Stripped Version) ASTN',
#  'Get to You Again Mac Ayres',
#  'forgettable Yaeow',
#  'Love Letter G9',
#  'Forget About You (Intimate) Devin Kennedy',
#  'If i am without u Yaeow',
#  'all ur fault ASTN',
#  'a song for when you fall in love Yaeow',
#  'phases (Acoustic) SOLOMON',
#  'Follow Through (Intimate) Devin Kennedy',
#  'Crush On You Finding Hope',
#  'Pinky Promise Ant Clemons',
#  'Strangers Finding Hope',
#  "WHAT'S IT GONNA TAKE ASTN",
#  'Good Man Walker',
#  'that shit is on you (Explicit Ver.) Walker',
#  "I'll Be Right Here Walker",
#  'Close to You potsu',
#  "Won't Be Here Long Walker",
#  "Don't Wake Me Moonchild",
#  "It's Not (Her Eyes) Walker",
#  'If I Had to Write a Song About You Aaron Taylor',
#  'Peace Of Mind Dream Walker',
#  'Summer 92914',
#  'Back to Me (Acoustic) Moonchild',
#  'Sweet Thing Walker',
#  'To the Moon Isaac Waddington',
#  'Nothing Better Brasstracks, Father Dude, John Splithoff',
#  'days like this John K',
#  'Yawn Nick Dorian',
#  'I Wonder M.I.L.K.',
#  'Brand New Public Library Commute',
#  'Black Coffee AVIV, OCTAVIO the Dweeb',
#  'miss me yet (bump) again&again',
#  'When You Love Somebody Robin Thicke',
#  'Jean Leon Micah Edwards',
#  'be careful with my heart Rocco',
#  'Till There Was You Imaginary Future',
#  'Dream a Little Dream of Me Kina Grannis',
#  'I Will Spend My Whole Life Loving You Imaginary Future, Kina Grannis',
#  "Don't Know Why Imaginary Future",
#  'Beyond the Sea Kina Grannis',
#  'What a Wonderful World Imaginary Future, Kina Grannis',
#  'L-O-V-E Imaginary Future',
#  'Somebody Loved Kina Grannis',
#  'Moon River Kina Grannis',
#  'How Sweet It Is (To Be Loved By You) Imaginary Future',
#  'In My Life Imaginary Future',
#  'We Are the Love We Give Imaginary Future',
#  "Don't Stop Believin' Imaginary Future",
#  "Don't Worry Baby Imaginary Future",
#  'Let It Be Imaginary Future',
#  'Moments Pink Sweat$',
#  'I Got You Bazzi',
#  '4Ever sunkis',
#  'Happier Than Ever ASTN',
#  'Casualties Ethan Dufault',
#  'Older (feat. Sierra Deaton) 5 Seconds of Summer',
#  'Another Day Gervs',
#  'Follow Through Devin Kennedy',
#  'almost happy elijah woods',
#  'Angel Baby (Acoustic) Troye Sivan',
#  'When I´m Still Getting Over You (Feat. Paige) Peder Elias',
#  'Walk Out That Door Ali Gatie',
#  'Youuu Milky Day (밀키데이), Gareth. T',
#  'How Much I Love You Matt Lv',
#  '이런 슬픈 노래 지소울 (GSoul)',
#  '17 (Acoustic) Pink Sweat$',
#  'In My Head 니브 (NIve)',
#  'would you love me now? Joshua Bassett',
#  'I Miss My Friends (feat. Phum Viphurit) Valentina Ploy',
#  'see my worth G. Nine',
#  'If (Original Movie Soundtrack from "Yung Libro Sa Napanood Ko") mrld',
#  'Sky is the Limit Mark Ambor',
#  'Cape 수지 (Suzy)',
#  '사랑 없이 사는게 왜 그렇게 어려울까요 겸 (GYE0M)',
#  '우리들의 아픔을 잃길 바랐는데 겸 (GYE0M)',
#  '잔상화 겸 (GYE0M)',
#  'salty 데이먼스 이어 (Damons year)',
#  'EVERYTHING 검정치마',
#  'Instant Lover 알레프 (ALEPH)',
#  '사랑은 내게 비극이어라 겸 (GYE0M)',
#  '14:30 데이먼스 이어 (Damons year)',
#  'No way home off the menu (오프더메뉴)',
#  '바람, 어디에서 부는지 오존 (O3ohn)',
#  '피와 갈증 (King of Hurts) 검정치마',
#  'August 데이먼스 이어 (Damons year)',
#  '서로를 안으며 겸 (GYE0M)',
#  '운명론 겸 (GYE0M)',
#  'Rainbow 데이먼스 이어 (Damons year)',
#  '나랑 아니면 검정치마',
#  'Tabacco 로쿠 (roku)',
#  '우린 마를 리 없었지 겸 (GYE0M)',
#  '우린 끝내 버티지 못했어 (with 김결) 겸 (GYE0M)',
#  'Bonfire Peder Elias',
#  'Mariposa Peach Tree Rascals',
#  'All for You (Feat. Theo Juarez) Micah Edwards',
#  'NO THING John OFA Rhee',
#  "Missin' You Like Crazy Us The Duo",
#  'Got A Love Sam Ock',
#  'Do You Want to Know a Secret Mathilda Homer',
#  'Mr & Mrs Brown Luisa Sobral',
#  'Serendipity Albert Posis',
#  'Sentimental Mood 와사비호텔 (wasabi hotel)',
#  'cheeze (Feat. Andrew Kang) Sarah Kang',
#  'One In A Million (Feat. Stefani Kimber) Jesse Gold',
#  'Nothing More Gabe Bondoc',
#  'In Your Wonderland Teddy Adhitya',
#  'Bitterlove Ardhito Pramono',
#  'Everyday Feels Like Sunday Jesse Barrera, Albert Posis',
#  'Little Things (Feat. YELO) TJ Monterde',
#  'Two Sleepy People Carsie Blanton',
#  'Breaking Patterns Jason LaPierre, Braiden Sunshine',
#  'Sunkissed (again&again Remix) Khai Dreams',
#  'Orange Splash (feat. 진동욱) 정바스 (J.BASS)',
#  'Tuscany Anja Kotar',
#  'Plaza Avenue Ardhito Pramono',
#  'LIMBO keshi',
#  'Get to You Again Mac Ayres',
#  "i swear i'll never leave again keshi",
#  'Honesty Pink Sweat$',
#  'UNDERSTAND keshi',
#  'I find peace in the rain slchld',
#  'Castle Rock Nieman',
#  'Higher Dylan Bernard',
#  'Cold Hearted Alex Holtti',
#  'August 7:28 P.M. homezone',
#  'Chains Pink Sweat$',
#  'Just Perfect curv moon',
#  'Malibu Nights LANY',
#  'Nightlight Finding Hope',
#  'Never Give Up Mira',
#  "IT'S YOU (feat. keshi) MAX",
#  'Whatever This Is Fern.',
#  'FEELINGS Timmy Albert',
#  'all i need (the distance song) Avery Lynch',
#  'Butterflies (Acoustic) Abe Parker',
#  'Six Feet Apart Alec Benjamin',
#  'hell or flying Jeremy Zucker',
#  'Clouds Before You Exit',
#  'On Our Own Bruno Major',
#  'What We Found Jesse Barrera, Nieman, Melissa Polinar',
#  'Dishes (Acoustic) Lauv',
#  'Behind the Clouds Yaeow',
#  'Up, Up & Away Chance Pena',
#  'With Love, Eugene Sofia Mills',
#  'emily Jeremy Zucker, Chelsea Cutler',
#  'Sad Girl Yaeow',
#  'Blue Elina',
#  'this is how you fall in love Jeremy Zucker, Chelsea Cutler',
#  'The Last Light Lily Kershaw',
#  "Don't You Worry Oh Wonder",
#  'Town I Called My Home Yaeow',
#  'Blue Sky Harvest Son, Shells',
#  'Not Your Fault (Hey You) Yaeow',
#  'It Might As Well Be Spring Stacey Kent',
#  'Goodnight My Love Rachael & Vilray',
#  'Don’t Cry Baby Madeleine Peyroux',
#  'In A World Of My Own Diana Panton',
#  'Any Little Time Rachael & Vilray',
#  'Is a Good Man Real? Rachael & Vilray',
#  'La Vie en Rose / La Vie en Rose Teshima Aoi (테시마 아오이 / 手島 葵)',
#  'Pick You Up Emmaline',
#  'Just Two Rachael & Vilray',
#  'Destination Moon (Feat. Don Thompson, Reg Schwager) Diana Panton',
#  'The Summer Wind Madeleine Peyroux',
#  'Hate is the Basis (of Love) Rachael & Vilray',
#  'Why Do I? Rachael & Vilray',
#  'Spring Cleaning Girls from Mars',
#  'Love On Top Hailey Tuck',
#  'ice cream at the konbini (feat. Sarah Hemi & Late Lee) mr.hong(미스터 홍), pastels',
#  'Prettiest To Me HYBS',
#  "mom I'm famous Gareth.T",
#  'Old Love (Stripped) yuji, putri dahlia',
#  "Life We've Built Portair, Emily James",
#  'over the moon Arash Buana',
#  'Room at the Table Charlie Lim (찰리 림)',
#  'To The Moon HOHYUN',
#  'Better Sunday Moon',
#  'A Million Songs (Feat. Marle Thomson) Anthony Lazaro',
#  'Duet Rachael Yamagata',
#  'Blue Moon Chet Baker',
#  "You're Mine, You! Chet Baker",
#  'Get to You Again Mac Ayres',
#  'Kiss Deal Anthony Lazaro',
#  'Sweet Sue, Just You Chet Baker',
#  'Shiver Tomo',
#  "You Don't Know Me Peter Manos",
#  'The Night We Called It A Day Chet Baker',
#  'Jack Rabbit (Live) King Louie & Baby James',
#  'i love you Sarah Hemi',
#  'In The Wee Small Hours Of The Morning Joey Stamper',
#  'Till There Was You Imaginary Future',
#  'La Vie En Rose Emily Watts',
#  'Paris New West',
#  'come into my arms November Ultra',
#  'Everyone Adores You (quiet) Matt Maltese',
#  'Keep Me Novo Amor',
#  'million little reasons Oscar Lang',
#  'Can You Feel the Love Tonight Anson Seabra',
#  'If the World Falls to Pieces Young Summer',
#  'Elliot\'s Song (From "Euphoria" An HBO Original Series) Dominic Fike, Zendaya',
#  'Lover / / Over the Moon Alice Phoebe Lou',
#  'ur so pretty Wasia Project',
#  'When You Wash Your Hair Matt Maltese',
#  'No Fun Novo Amor, Gia Margaret',
#  "Gershwin : Porgy And Bess Act.II - Honey, Dat's All De Breakfast...Take You' Hands Off M,E Arthur Thompson, William Brown, Leona Mitchell, Florence Quivar, Christopher Deane, Barbara Conrad",
#  'Tin Lover The Paper Kites',
#  'Teeth Billie Marten',
#  "Gershwin : Porgy And Bess Act.II - Honey, Dat's All De Breakfast...Take You' Hands Off M,E Arthur Thompson, William Brown, Leona Mitchell, Florence Quivar, Christopher Deane, Barbara Conrad",
#  "A Soulmate Who Wasn't Meant to Be Jess Benko",
#  'Paper Thin Hotel Matt Maltese',
#  'Learning to Hate You as a Self Defense Mechanism Flatsound',
#  'now that i know you Julian',
#  'Drown Boy In Space',
#  'made for you mike martell',
#  "She's Everything That I've Ever Wanted Caleb Hearn",
#  'If I Really Love You Lexi Jayde',
#  'Aegean push baby',
#  'Too and More (Live) Mikha Angelo',
#  'Falling into You Blake Proehl',
#  'Missing Her So Atli',
#  'brokenhearted (sunset) joan',
#  'Love Like That (Words from Her) Suriel Hess',
#  'I Tell All My Friends About You (Stripped) lullaboy',
#  'Follow Through (Intimate) Devin Kennedy',
#  'Slow Dance In The Morning Jesse Gold',
#  'Follow Through (Intimate) Devin Kennedy',
#  'Make a Memory Bobbi Ruffin',
#  'dinner in bed Gareth.T',
#  'Tango Nieman, Sarah Kang, Casey Lagos',
#  'Forget About You (Intimate) Devin Kennedy',
#  'For You 샘김 (Sam Kim)',
#  "Writer's Block Dylan Bernard",
#  'Long Time No See Gervs',
#  'Sick of You Suriel Hess',
#  'Can You Love Me Tonight? - Stripped Kairo',
#  'Rich Lily Williams',
#  'over the moon Arash Buana',
#  'Perfume Mehro',
#  'Two Sleepy People Carsie Blanton',
#  "'S Wonderful (Bonus Track) Kat Edmonson",
#  'Tout Doucement Blossom Dearie',
#  'Dream A Little Dream Silje Nergaard',
#  'All I Do Is Dream Of You (Feat. D) Stacey Kent',
#  "It's a Good Day Matthieu Bore",
#  'I Wish You Love Nancy Wilson',
#  'It Might As Well Be Spring Stacey Kent',
#  'Heavenly Thing Carsie Blanton',
#  'Spring Cleaning Girls from Mars',
#  "They Say It's Spring Blossom Dearie",
#  'Destination Moon (Feat. Don Thompson, Reg Schwager) Diana Panton',
#  'On The Sunny Side Of The Street Alexis Cole, Bucky Pizzarelli',
#  'Mountain Greenery Kat Edmonson, Vince Giordano And The Nighthawks',
#  "It's De-Lovely Jeri Southern",
#  'Rainger: Easy Living Andrea Motis & Joan Chamorro',
#  "I've Missed You Faime",
#  'colorblind Mokita',
#  '7 Stories Valley',
#  'Soul Mate Flora Cash',
#  'Be My Mistake The 1975',
#  'Blue Elina',
#  'Clear Eyes Mokita',
#  'I Wish Faime',
#  'all i need (the distance song) Avery Lynch',
#  'Ordinary People Blake Rose',
#  'About You (Andre Visior Mix Cut) (feat. Dave Thomas Junior) REZarin',
#  'Into The Deep Emmit Fenn',
#  "I Don't Wanna Know James Smith",
#  'How Elina',
#  'Another Round Elina',
#  'I Didn`t Love You Portair',
#  'Iris Kina Grannis',
#  'Jack Rabbit (Live) King Louie & Baby James',
#  'Time To Rest Your Weary Head Jacob Collier',
#  'love (ain\x92t always so good) isaac gracie',
#  'When You Wash Your Hair Matt Maltese',
#  "Honey, It's Alright Gregory Alan Isakov",
#  'In The Morning Nicole Reynolds',
#  'Go Downstairs to the Blue Moon, Buy Some Fried Chicken Bubble Tea and Cigarettes',
#  '5AM Empanada with You Bubble Tea and Cigarettes',
#  'Sunsetz Cigarettes After Sex',
#  'Leap Bubble Tea and Cigarettes',
#  'Apocalypse Cigarettes After Sex',
#  'John Wayne Cigarettes After Sex',
#  'Liz Bubble Tea and Cigarettes',
#  'Truly Cigarettes After Sex',
#  'Crush Cigarettes After Sex',
#  'Santa Monica Bubble Tea and Cigarettes',
#  'Sesame Syrup Cigarettes After Sex',
#  'Sweet Cigarettes After Sex',
#  'Touch Cigarettes After Sex',
#  'K. Cigarettes After Sex',
#  'us keshi',
#  'Castle Rock Nieman',
#  'Simple (Feat. lewloh) Jawn',
#  'yellow lights Finding Hope',
#  'UNDERSTAND keshi',
#  'I find peace in the rain slchld',
#  'Somehow 오존 (O3ohn)',
#  "If You Don't Yaeow",
#  "i swear i'll never leave again keshi",
#  'Looking For Sonny Zero',
#  'Behind the Clouds Yaeow',
#  'Without You (feat. Holly Drummond) Finding Hope',
#  'Strangers Finding Hope',
#  "If You're Not the One for Me Who Is keshi",
#  'Mendelssohn : Hark! The Herald Angels Sing (멘델스존 : 천사 찬송하기를) (After Mendelssohn\'s Festgesang, WoO 9 "Vaterland dein Grauen") Westminster Cathedral Choir, The Alexander Choir, The Cantorum Choir, David Hill, Duncan Beat',
#  'Velvet & Lace Addict., Brodie Barclay',
#  'disappear demxntia (디멘시아)',
#  "I'm Not The One Yaeow",
#  ...]

# %%
song_unique_list = df['song'].unique().tolist()
len(song_unique_list)
# Out:
# 11081

# %%
song_df = pd.DataFrame(song_unique_list)
song_df.head(3)
# Out:
#                                    0
# 0  Until I Found You Stephen Sanchez
# 1         IT'S YOU (feat. keshi) MAX
# 2                   UNDERSTAND keshi

# %%
# 리스트 길이를 계산하고 반으로 나눔
mid_index = len(song_unique_list) // 2

# 리스트를 두 개로 분할
first_half = song_unique_list[:mid_index]
second_half = song_unique_list[mid_index:]

# %%
driver = wb.Chrome()
    # YouTube 플레이리스트 URL로 이동
driver.get('https://www.youtube.com/')

# %%
search = driver.find_element("name", "search_query")

# %%
search.clear()
search.send_keys('Until I Found You Stephen Sanchez')

# %%
search.send_keys(Keys.ENTER)
time.sleep(2)

# %%
link = driver.find_element(By.CSS_SELECTOR, "#video-title")
link.get_attribute('href')
# Out:
# 'https://www.youtube.com/watch?v=GxldQ9eX2wo&pp=ygUhVW50aWwgSSBGb3VuZCBZb3UgU3RlcGhlbiBTYW5jaGV6'

# %%
btn = driver.find_element(By.CSS_SELECTOR, "#thumbnail > yt-image > img")
btn.click()

# %%
btn = driver.find_element(By.CSS_SELECTOR, "#top-level-buttons-computed > yt-button-view-model > button-view-model > button > yt-touch-feedback-shape > div > div.yt-spec-touch-feedback-shape__fill")
btn.click()

# %%
btn = driver.find_element(By.CSS_SELECTOR, "#target > yt-icon > yt-icon-shape > icon-shape > div")
btn.click()

# %%
value = driver.find_element(By.CSS_SELECTOR, "#textarea")

# %%
textarea_value = value.get_attribute('value')

# %%
youtube_iframe.append(textarea_value)
# Out:
# '<iframe width="560" height="315" src="https://www.youtube.com/embed/GxldQ9eX2wo?si=cr8aZICNYzwksbR0" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>'

# %%
btn = driver.find_element(By.CSS_SELECTOR, "#close-panel-icon > yt-icon-shape > icon-shape > div")
btn.click()

# %%
driver = wb.Chrome(options=options)
    # YouTube 플레이리스트 URL로 이동
driver.get('https://www.youtube.com/')
youtube_iframe1 = []

for song in tqdm(first_half):
    try:
        # 검색 창 찾기 및 노래 검색
        search = driver.find_element(By.NAME, "search_query")
        search.clear()
        search.send_keys(song)
        search.send_keys(Keys.ENTER)
        
        # 랜덤으로 대기 시간을 설정
        time.sleep(random.uniform(3, 4))
        
        # 동영상 클릭
        btn = driver.find_element(By.CSS_SELECTOR, "#video-title")
        value =btn.get_attribute('href')

        youtube_iframe1.append(value)
    except Exception as e:
        print(f"Error processing '{song}': {e}")
        youtube_iframe1.append(None)
    
driver.quit()
# Out:
#   0%|          | 0/5540 [00:00<?, ?it/s]
# Error processing 'Mozart : The Magic Flute K.620 Act.II - Queen Of The Night Aria 'Der Holle Rache' (모차르트 : 마술 피리 - 2막. 밤의 여왕의 아리아) (From "Amadeus") Bulgarian National Radio Symphony Orchestra, John Landor, Rachel Rosales': Message: no such element: Unable to locate element: {"method":"css selector","selector":"#video-title"}
#   (Session info: chrome-headless-shell=125.0.6422.142); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6203B1F52+60322]
# 	(No symbol) [0x00007FF62032CEC9]
# 	(No symbol) [0x00007FF6201E7EBA]
# 	(No symbol) [0x00007FF620237676]
# 	(No symbol) [0x00007FF62023773C]
# 	(No symbol) [0x00007FF62027E967]
# 	(No symbol) [0x00007FF62025C25F]
# 	(No symbol) [0x00007FF62027BC80]
# 	(No symbol) [0x00007FF62025BFC3]
# 	(No symbol) [0x00007FF620229617]
# 	(No symbol) [0x00007FF62022A211]
# 	GetHandleVerifier [0x00007FF6206C94AD+3301629]
# 	GetHandleVerifier [0x00007FF6207136D3+3605283]
# 	GetHandleVerifier [0x00007FF620709450+3563680]
# 	GetHandleVerifier [0x00007FF620464326+790390]
# 	(No symbol) [0x00007FF62033750F]
# 	(No symbol) [0x00007FF620333404]
# 	(No symbol) [0x00007FF620333592]
# 	(No symbol) [0x00007FF620322F9F]
# 	BaseThreadInitThunk [0x00007FFD22237344+20]
# 	RtlUserThreadStart [0x00007FFD23F626B1+33]

# %%
iframe_df1 = pd.DataFrame(youtube_iframe1, columns=['iframe'])
iframe_df1.to_csv('유튜브iframe정보1.csv',index=False,encoding='utf-8-sig')

# %%
driver = wb.Chrome(options=options)
    # YouTube 플레이리스트 URL로 이동
driver.get('https://www.youtube.com/')
youtube_iframe2 = []

for song in tqdm(second_half):
    try:
        # 검색 창 찾기 및 노래 검색
        search = driver.find_element(By.NAME, "search_query")
        search.clear()
        search.send_keys(song)
        search.send_keys(Keys.ENTER)
        
        # 랜덤으로 대기 시간을 설정
        time.sleep(random.uniform(3, 4))
        
        # 동영상 클릭
        btn = driver.find_element(By.CSS_SELECTOR, "#video-title")
        value =btn.get_attribute('href')

        youtube_iframe2.append(value)
    except Exception as e:
        print(f"Error processing '{song}': {e}")
        youtube_iframe2.append(None)
    
driver.quit()
# Out:
#   0%|          | 0/5541 [00:00<?, ?it/s]
# Error processing 'We're All Gonna Die Olivia O'Brien': Message: no such element: Unable to locate element: {"method":"css selector","selector":"#video-title"}
#   (Session info: chrome-headless-shell=125.0.6422.144); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF77C2A1F52+60322]
# 	(No symbol) [0x00007FF77C21CEC9]
# 	(No symbol) [0x00007FF77C0D7EBA]
# 	(No symbol) [0x00007FF77C127676]
# 	(No symbol) [0x00007FF77C12773C]
# 	(No symbol) [0x00007FF77C16E967]
# 	(No symbol) [0x00007FF77C14C25F]
# 	(No symbol) [0x00007FF77C16BC80]
# 	(No symbol) [0x00007FF77C14BFC3]
# 	(No symbol) [0x00007FF77C119617]
# 	(No symbol) [0x00007FF77C11A211]
# 	GetHandleVerifier [0x00007FF77C5B94AD+3301629]
# 	GetHandleVerifier [0x00007FF77C6036D3+3605283]
# 	GetHandleVerifier [0x00007FF77C5F9450+3563680]
# 	GetHandleVerifier [0x00007FF77C354326+790390]
# 	(No symbol) [0x00007FF77C22750F]
# 	(No symbol) [0x00007FF77C223404]
# 	(No symbol) [0x00007FF77C223592]
# 	(No symbol) [0x00007FF77C212F9F]
# 	BaseThreadInitThunk [0x00007FFE3F627344+20]
# 	RtlUserThreadStart [0x00007FFE3FBBCC91+33]

# %%
iframe_df2 = pd.DataFrame(youtube_iframe2, columns=['iframe'])
iframe_df2.to_csv('유튜브iframe정보2.csv',index=False,encoding='utf-8-sig')

# %%
df1 = pd.read_csv('유튜브iframe정보1.csv')
df2 = pd.read_csv('유튜브iframe정보2.csv')

# %%
pull_df = pd.concat([df1, df2])
pull_df
# Out:
#                                                  iframe
# 0     https://www.youtube.com/watch?v=GxldQ9eX2wo&pp...
# 1     https://www.youtube.com/watch?v=zWxuc8L0W_Y&pp...
# 2     https://www.youtube.com/watch?v=6DcUnqZqTvI&pp...
# 3     https://www.youtube.com/watch?v=SfrIHYu8u9c&pp...
# 4     https://www.youtube.com/watch?v=RI4CLyFhUAg&pp...
# ...                                                 ...
# 5536  https://www.youtube.com/watch?v=FVftpgsfw1o&pp...
# 5537  https://www.youtube.com/watch?v=SMJ3eTwzJKg&pp...
# 5538  https://www.youtube.com/watch?v=8yo9GCnM3jc&pp...
# 5539  https://www.youtube.com/watch?v=21aFacRNoWE&pp...
# 5540  https://www.youtube.com/watch?v=xYohdxG_izE&pp...
#
# [11081 rows x 1 columns]

# %%
song_df
# Out:
#                                          0
# 0        Until I Found You Stephen Sanchez
# 1               IT'S YOU (feat. keshi) MAX
# 2                         UNDERSTAND keshi
# 3                        stars Arash Buana
# 4      Till There Was You Imaginary Future
# ...                                    ...
# 11076   밤하늘의 저 별처럼 헤이즈 (Heize), 펀치 (Punch)
# 11077           SOON (Feat. BewhY) 다이나믹 듀오
# 11078           She Said (with BIBI) Crush
# 11079      Do It For Love (Feat. 죠지) THAMA
# 11080             몇번째 (Song By 찬현) KozyPop
#
# [11081 rows x 1 columns]

# %%
# 인덱스 초기화
song_df = song_df.reset_index(drop=True)
pull_df = pull_df.reset_index(drop=True)

# %%
youtube_df = pd.concat([song_df, pull_df], axis=1)
youtube_df
# Out:
#                                          0  \
# 0        Until I Found You Stephen Sanchez
# 1               IT'S YOU (feat. keshi) MAX
# 2                         UNDERSTAND keshi
# 3                        stars Arash Buana
# 4      Till There Was You Imaginary Future
# ...                                    ...
# 11076   밤하늘의 저 별처럼 헤이즈 (Heize), 펀치 (Punch)
# 11077           SOON (Feat. BewhY) 다이나믹 듀오
# 11078           She Said (with BIBI) Crush
# 11079      Do It For Love (Feat. 죠지) THAMA
# 11080             몇번째 (Song By 찬현) KozyPop
#
#                                                   iframe
# 0      https://www.youtube.com/watch?v=GxldQ9eX2wo&pp...
# 1      https://www.youtube.com/watch?v=zWxuc8L0W_Y&pp...
# 2      https://www.youtube.com/watch?v=6DcUnqZqTvI&pp...
# 3      https://www.youtube.com/watch?v=SfrIHYu8u9c&pp...
# 4      https://www.youtube.com/watch?v=RI4CLyFhUAg&pp...
# ...                                                  ...
# 11076  https://www.youtube.com/watch?v=FVftpgsfw1o&pp...
# 11077  https://www.youtube.com/watch?v=SMJ3eTwzJKg&pp...
# 11078  https://www.youtube.com/watch?v=8yo9GCnM3jc&pp...
# 11079  https://www.youtube.com/watch?v=21aFacRNoWE&pp...
# 11080  https://www.youtube.com/watch?v=xYohdxG_izE&pp...
#
# [11081 rows x 2 columns]

# %%
youtube_df.to_csv('유튜브iframe정보_pull.csv',index=False,encoding='utf-8-sig')
youtube_df.head(2)
# Out:
#                                    0  \
# 0  Until I Found You Stephen Sanchez
# 1         IT'S YOU (feat. keshi) MAX
#
#                                               iframe
# 0  https://www.youtube.com/watch?v=GxldQ9eX2wo&pp...
# 1  https://www.youtube.com/watch?v=zWxuc8L0W_Y&pp...

# %%
df
# Out:
#                                                 albumCov  \
# 0      https://cdnimg.melon.co.kr/cm2/album/images/10...
# 1      https://cdnimg.melon.co.kr/cm2/album/images/11...
# 2      https://cdnimg.melon.co.kr/cm2/album/images/10...
# 3      https://cdnimg.melon.co.kr/cm2/album/images/10...
# 4      https://cdnimg.melon.co.kr/cm2/album/images/11...
# ...                                                  ...
# 18647  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18648  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18649  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18650  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18651  https://cdnimg.melon.co.kr/cm2/album/images/10...
#
#                            title         artistIdx  \
# 0              Until I Found You   Stephen Sanchez
# 1         IT'S YOU (feat. keshi)               MAX
# 2                     UNDERSTAND             keshi
# 3                          stars       Arash Buana
# 4             Till There Was You  Imaginary Future
# ...                          ...               ...
# 18647                        찌질이               안재우
# 18648       She Said (with BIBI)             Crush
# 18649  Do It For Love (Feat. 죠지)             THAMA
# 18650           몇번째 (Song By 찬현)           KozyPop
# 18651   aura (Feat.샘김 (Sam Kim))                죠지
#
#                                albumIdx        genreIdx  releasedAt  \
# 0                     Until I Found You              포크  2021.09.01
# 1                        LOVE IN STEREO             POP  2024.02.16
# 2      GABRIEL (Korean Special Edition)             POP  2022.03.25
# 3                                 stars             POP  2021.02.28
# 4                    Till There Was You             POP  2023.05.02
# ...                                 ...             ...         ...
# 18647                               나쁜년  R&B/Soul, 인디음악  2021.01.05
# 18648                          with HER            랩/힙합  2020.10.20
# 18649                    Do It For Love        R&B/Soul  2020.06.24
# 18650                 Seoul Vibes Pt.15  R&B/Soul, 인디음악  2020.04.15
# 18651                             LEEEE        R&B/Soul  2019.10.03
#
#                                                   lyrics  year  \
# 0      Georgia, Wrap me up in all your...\r\nI want y...  2021
# 1      Mm-hmm, no-oh, yeah, yeah\r\n\r\nIt's you\r\nL...  2024
# 2      Never thought that I'd find\r\nThat the one in...  2022
# 3                                                    NaN  2021
# 4                                                    NaN  2023
# ...                                                  ...   ...
# 18647  그냥 그때 돌아서지 말걸\r\n라고 뱉으며 나 후회는\r\n한 백번 천번쯤에\r\n...  2021
# 18648  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...  2020
# 18649  아침햇살은 밝아\r\n텅 빈 하루를 살아 난\r\n나이는 적지 않아\r\n가끔씩 궁...  2020
# 18650  I love u 근데 나는 너무 아퍼\r\n내 맘을 아는 거면 너는 진짜 나뻐\r\...  2020
# 18651  you and me are different\r\nand i know it\r\n그...  2019
#
#                                       song
# 0        Until I Found You Stephen Sanchez
# 1               IT'S YOU (feat. keshi) MAX
# 2                         UNDERSTAND keshi
# 3                        stars Arash Buana
# 4      Till There Was You Imaginary Future
# ...                                    ...
# 18647                              찌질이 안재우
# 18648           She Said (with BIBI) Crush
# 18649      Do It For Love (Feat. 죠지) THAMA
# 18650             몇번째 (Song By 찬현) KozyPop
# 18651          aura (Feat.샘김 (Sam Kim)) 죠지
#
# [18652 rows x 9 columns]

# %%
# 리스트를 딕셔너리로 변환
youtube_dict = dict(zip(df['song'], youtube_df['iframe']))

# %%
df['youtube'] = df['song']
df.head(3)
# Out:
#                                             albumCov                   title  \
# 0  https://cdnimg.melon.co.kr/cm2/album/images/10...       Until I Found You
# 1  https://cdnimg.melon.co.kr/cm2/album/images/11...  IT'S YOU (feat. keshi)
# 2  https://cdnimg.melon.co.kr/cm2/album/images/10...              UNDERSTAND
#
#          artistIdx                          albumIdx genreIdx  releasedAt  \
# 0  Stephen Sanchez                 Until I Found You       포크  2021.09.01
# 1              MAX                    LOVE IN STEREO      POP  2024.02.16
# 2            keshi  GABRIEL (Korean Special Edition)      POP  2022.03.25
#
#                                               lyrics  year  \
# 0  Georgia, Wrap me up in all your...\r\nI want y...  2021
# 1  Mm-hmm, no-oh, yeah, yeah\r\n\r\nIt's you\r\nL...  2024
# 2  Never thought that I'd find\r\nThat the one in...  2022
#
#                                 song                            youtube
# 0  Until I Found You Stephen Sanchez  Until I Found You Stephen Sanchez
# 1         IT'S YOU (feat. keshi) MAX         IT'S YOU (feat. keshi) MAX
# 2                   UNDERSTAND keshi                   UNDERSTAND keshi

# %%
df['youtube'] = df['youtube'].map(youtube_dict)
df
# Out:
#                                                 albumCov  \
# 0      https://cdnimg.melon.co.kr/cm2/album/images/10...
# 1      https://cdnimg.melon.co.kr/cm2/album/images/11...
# 2      https://cdnimg.melon.co.kr/cm2/album/images/10...
# 3      https://cdnimg.melon.co.kr/cm2/album/images/10...
# 4      https://cdnimg.melon.co.kr/cm2/album/images/11...
# ...                                                  ...
# 18647  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18648  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18649  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18650  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 18651  https://cdnimg.melon.co.kr/cm2/album/images/10...
#
#                            title         artistIdx  \
# 0              Until I Found You   Stephen Sanchez
# 1         IT'S YOU (feat. keshi)               MAX
# 2                     UNDERSTAND             keshi
# 3                          stars       Arash Buana
# 4             Till There Was You  Imaginary Future
# ...                          ...               ...
# 18647                        찌질이               안재우
# 18648       She Said (with BIBI)             Crush
# 18649  Do It For Love (Feat. 죠지)             THAMA
# 18650           몇번째 (Song By 찬현)           KozyPop
# 18651   aura (Feat.샘김 (Sam Kim))                죠지
#
#                                albumIdx        genreIdx  releasedAt  \
# 0                     Until I Found You              포크  2021.09.01
# 1                        LOVE IN STEREO             POP  2024.02.16
# 2      GABRIEL (Korean Special Edition)             POP  2022.03.25
# 3                                 stars             POP  2021.02.28
# 4                    Till There Was You             POP  2023.05.02
# ...                                 ...             ...         ...
# 18647                               나쁜년  R&B/Soul, 인디음악  2021.01.05
# 18648                          with HER            랩/힙합  2020.10.20
# 18649                    Do It For Love        R&B/Soul  2020.06.24
# 18650                 Seoul Vibes Pt.15  R&B/Soul, 인디음악  2020.04.15
# 18651                             LEEEE        R&B/Soul  2019.10.03
#
#                                                   lyrics  year  \
# 0      Georgia, Wrap me up in all your...\r\nI want y...  2021
# 1      Mm-hmm, no-oh, yeah, yeah\r\n\r\nIt's you\r\nL...  2024
# 2      Never thought that I'd find\r\nThat the one in...  2022
# 3                                                    NaN  2021
# 4                                                    NaN  2023
# ...                                                  ...   ...
# 18647  그냥 그때 돌아서지 말걸\r\n라고 뱉으며 나 후회는\r\n한 백번 천번쯤에\r\n...  2021
# 18648  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...  2020
# 18649  아침햇살은 밝아\r\n텅 빈 하루를 살아 난\r\n나이는 적지 않아\r\n가끔씩 궁...  2020
# 18650  I love u 근데 나는 너무 아퍼\r\n내 맘을 아는 거면 너는 진짜 나뻐\r\...  2020
# 18651  you and me are different\r\nand i know it\r\n그...  2019
#
#                                       song  \
# 0        Until I Found You Stephen Sanchez
# 1               IT'S YOU (feat. keshi) MAX
# 2                         UNDERSTAND keshi
# 3                        stars Arash Buana
# 4      Till There Was You Imaginary Future
# ...                                    ...
# 18647                              찌질이 안재우
# 18648           She Said (with BIBI) Crush
# 18649      Do It For Love (Feat. 죠지) THAMA
# 18650             몇번째 (Song By 찬현) KozyPop
# 18651          aura (Feat.샘김 (Sam Kim)) 죠지
#
#                                                  youtube
# 0      https://www.youtube.com/watch?v=yFPZkd9pPG8&pp...
# 1      https://www.youtube.com/watch?v=7fVeHu1An2k&pp...
# 2      https://www.youtube.com/watch?v=CwaS3G2TG-c&pp...
# 3      https://www.youtube.com/watch?v=n2MmZSkkLXw&pp...
# 4      https://www.youtube.com/watch?v=3jwwqoLA1eQ&pp...
# ...                                                  ...
# 18647                                                NaN
# 18648                                                NaN
# 18649                                                NaN
# 18650                                                NaN
# 18651                                                NaN
#
# [18652 rows x 10 columns]

# %%
df['youtube'].to_csv('iframe_full.csv',index=False,encoding='utf-8-sig')

# %%
you_df = pd.read_csv('iframe_full.csv')
you_df
# Out:
#                                                  youtube
# 0      https://www.youtube.com/watch?v=yFPZkd9pPG8&pp...
# 1      https://www.youtube.com/watch?v=7fVeHu1An2k&pp...
# 2      https://www.youtube.com/watch?v=CwaS3G2TG-c&pp...
# 3      https://www.youtube.com/watch?v=n2MmZSkkLXw&pp...
# 4      https://www.youtube.com/watch?v=3jwwqoLA1eQ&pp...
# ...                                                  ...
# 18647                                                NaN
# 18648                                                NaN
# 18649                                                NaN
# 18650                                                NaN
# 18651                                                NaN
#
# [18652 rows x 1 columns]

# %%
you_df['youtube'][0]
# Out:
# 'https://www.youtube.com/watch?v=yFPZkd9pPG8&pp=ygUbUEFDS0lUVVAhIChwcm9kLiBCTVRKKSBwSC0x'

# %%
# 비디오 ID를 추출하는 함수
def extract_video_id(url):
    pattern = r"v=([a-zA-Z0-9_-]{11})"
    match = re.search(pattern, url)
    if match:
        return match.group(1)
    else:
        return None

# %%
you_df['youtube'] = you_df['youtube'].str.extract(r"v=([a-zA-Z0-9_-]{11})")[0]
you_df
# Out:
#            youtube
# 0      yFPZkd9pPG8
# 1      7fVeHu1An2k
# 2      CwaS3G2TG-c
# 3      n2MmZSkkLXw
# 4      3jwwqoLA1eQ
# ...            ...
# 18647          NaN
# 18648          NaN
# 18649          NaN
# 18650          NaN
# 18651          NaN
#
# [18652 rows x 1 columns]

# %%
you_df['youtube'].to_csv('iframe_link_full.csv',index=False,encoding='utf-8-sig')

# %%
total_nan = you_df.isnull().sum().sum()
print(f"Total NaN values: {total_nan}")
# Out:
# Total NaN values: 4397

# %%
you_df = you_df.fillna('-')
you_df
# Out:
#            youtube
# 0      yFPZkd9pPG8
# 1      7fVeHu1An2k
# 2      CwaS3G2TG-c
# 3      n2MmZSkkLXw
# 4      3jwwqoLA1eQ
# ...            ...
# 18647            -
# 18648            -
# 18649            -
# 18650            -
# 18651            -
#
# [18652 rows x 1 columns]

# %%
you_df.to_csv('iframe_link_full_전처리.csv',index=False,encoding='utf-8-sig')

# %%
you_df
# Out:
#            youtube
# 0      yFPZkd9pPG8
# 1      7fVeHu1An2k
# 2      CwaS3G2TG-c
# 3      n2MmZSkkLXw
# 4      3jwwqoLA1eQ
# ...            ...
# 18647            -
# 18648            -
# 18649            -
# 18650            -
# 18651            -
#
# [18652 rows x 1 columns]

# %%
import json
import re
import pandas as pd
import csv
import pymysql

import pymysql
conn = pymysql.connect(
        host='project-db-cgi.smhrd.com',
        port=3307,
        user='ehroqkfdbcah',
        password='q1w2e3!@#',
        db='ehroqkfdbcah',
        charset='utf8'
    )

# MySQL 커서 생성
cursor = conn.cursor()

# CSV 파일 경로
csv_file_path = "iframe_link_full_전처리.csv"

# CSV 파일 읽기
with open(csv_file_path, 'r', encoding='utf-8') as csv_file:
    csv_reader = csv.reader(csv_file)
    # 첫 번째 행은 헤더이므로 건너뜁니다
    next(csv_reader)
    rows = list(csv_reader)

# MySQL 테이블 이름
table_name = "tb_music"

# SQL 쿼리 생성
sql = f"INSERT INTO {table_name} (iframe) VALUES (%s)"

# CSV 데이터를 MySQL 데이터베이스에 삽입
for row in tqdm(rows):
    cursor.execute(sql, row)

# 변경 사항 커밋
conn.commit()

# MySQL 연결 종료
conn.close()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 18652/18652 [05:08<00:00, 60.37it/s]

# %% [markdown]
# ### process 죽이기

# %%
import pymysql

# MySQL 연결 설정
conn = pymysql.connect(
    host='project-db-cgi.smhrd.com',
    port=3307,
    user='ehroqkfdbcah',
    password='q1w2e3!@#',
    db='ehroqkfdbcah',
    charset='utf8'
)

# MySQL 커서 생성
cursor = conn.cursor()

# 특정 상태의 모든 프로세스 ID를 가져오는 쿼리
query = "SHOW PROCESSLIST"
cursor.execute(query)
processes = cursor.fetchall()

# 'Sleep' 상태의 프로세스 ID를 수집
sleep_process_ids = [process[0] for process in processes if process[4] == 'Sleep']

# 각 'Sleep' 상태의 프로세스를 종료
for pid in sleep_process_ids:
    try:
        cursor.execute(f"KILL {pid};")
    except pymysql.MySQLError as e:
        print(f"Error killing process {pid}: {e}")

# 변경 사항 커밋
conn.commit()

# MySQL 연결 종료
conn.close()

# %%
import pymysql

# MySQL 연결 설정
conn = pymysql.connect(
    host='project-db-cgi.smhrd.com',
    port=3307,
    user='ehroqkfdbcah',
    password='q1w2e3!@#',
    db='ehroqkfdbcah',
    charset='utf8'
)

# MySQL 커서 생성
cursor = conn.cursor()

# 현재 연결된 프로세스 확인
cursor.execute("SHOW PROCESSLIST;")
processes = cursor.fetchall()

# 종료할 프로세스 ID 목록 (필요한 경우 업데이트)
process_ids = [
    304339, 304362, 304363, 304387, 304388,
    304412, 304413, 304459, 304476, 304477
]

# 각 프로세스를 종료
for process in processes:
    pid = process[0]
    if pid in process_ids:
        try:
            cursor.execute(f"KILL {pid};")
            print(f"Successfully killed process {pid}")
        except pymysql.MySQLError as e:
            print(f"Error killing process {pid}: {e}")

# 변경 사항 커밋
conn.commit()

# `iframe` 열 삭제
try:
    cursor.execute("ALTER TABLE `ehroqkfdbcah`.`tb_music` DROP COLUMN `iframe`;")
    conn.commit()
    print("Successfully dropped the 'iframe' column.")
except pymysql.MySQLError as e:
    print(f"Error dropping 'iframe' column: {e}")

# MySQL 연결 종료
conn.close()
# Out:
# Error dropping 'iframe' column: (1091, "Can't DROP 'iframe'; check that column/key exists")

# %%
import pymysql

# MySQL 연결 설정
conn = pymysql.connect(
    host='project-db-cgi.smhrd.com',
    port=3307,
    user='ehroqkfdbcah',
    password='q1w2e3!@#',
    db='ehroqkfdbcah',
    charset='utf8'
)

# MySQL 커서 생성
cursor = conn.cursor()

# `iframe` 컬럼 생성
try:
    cursor.execute("ALTER TABLE tb_music ADD COLUMN iframe VARCHAR(256) DEFAULT NULL;")
    conn.commit()
    print("Successfully added the 'iframe' column.")
except pymysql.MySQLError as e:
    print(f"Error adding 'iframe' column: {e}")

# MySQL 연결 종료
conn.close()
# Out:
# Successfully added the 'iframe' column.

# %%
import csv
from tqdm import tqdm
import pymysql

# MySQL 연결 설정
conn = pymysql.connect(
    host='project-db-cgi.smhrd.com',
    port=3307,
    user='ehroqkfdbcah',
    password='q1w2e3!@#',
    db='ehroqkfdbcah',
    charset='utf8'
)

# MySQL 커서 생성
cursor = conn.cursor()

# CSV 파일 경로
csv_file_path = "iframe_link_full_전처리.csv"

# CSV 파일 읽기
with open(csv_file_path, 'r', encoding='utf-8') as csv_file:
    csv_reader = csv.reader(csv_file)
    # 첫 번째 행은 헤더이므로 건너뜁니다
    next(csv_reader)
    rows = list(csv_reader)

# MySQL 테이블 이름
table_name = "tb_music"

# SQL 쿼리 생성
# 여기서는 'id'가 기본 키라고 가정합니다.
for row in tqdm(rows):
    iframe_value = row[0]  # 필요한 열의 인덱스에 맞게 조정
    try:
        cursor.execute(f"INSERT INTO {table_name} (iframe) VALUES (%s) ON DUPLICATE KEY UPDATE iframe=VALUES(iframe);", (iframe_value,))
    except pymysql.MySQLError as e:
        print(f"Error inserting iframe value: {e}")

# 변경 사항 커밋
conn.commit()

# MySQL 연결 종료
conn.close()
# Out:
#   0%|                                                                                | 7/18652 [00:00<04:50, 64.10it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   0%|                                                                               | 21/18652 [00:00<04:57, 62.65it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   0%|▏                                                                              | 35/18652 [00:00<04:52, 63.71it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   0%|▏                                                                              | 49/18652 [00:00<05:00, 61.83it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   0%|▎                                                                              | 63/18652 [00:01<05:02, 61.42it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   0%|▎                                                                              | 77/18652 [00:01<05:09, 59.96it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   0%|▍                                                                              | 91/18652 [00:01<05:01, 61.52it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   1%|▍                                                                             | 105/18652 [00:01<04:52, 63.33it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   1%|▍                                                                             | 119/18652 [00:01<04:51, 63.69it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   1%|▌                                                                             | 133/18652 [00:02<04:46, 64.71it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   1%|▌                                                                             | 147/18652 [00:02<04:50, 63.74it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   1%|▋                                                                             | 161/18652 [00:02<04:47, 64.29it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   1%|▋                                                                             | 168/18652 [00:02<04:46, 64.60it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   1%|▊                                                                             | 182/18652 [00:02<04:46, 64.45it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   1%|▊                                                                             | 196/18652 [00:03<04:47, 64.19it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   1%|▉                                                                             | 210/18652 [00:03<04:47, 64.13it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
#   1%|▉                                                                             | 226/18652 [00:03<04:52, 63.06it/s]
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# Error inserting iframe value: (1054, "Unknown column 'iframe' in 'field list'")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[82], line 36
#      34 iframe_value = row[0]  # 필요한 열의 인덱스에 맞게 조정
#      35 try:
# ---> 36     cursor.execute(f"INSERT INTO {table_name} (iframe) VALUES (%s) ON DUPLICATE KEY UPDATE iframe=VALUES(iframe);", (iframe_value,))
#      37 except pymysql.MySQLError as e:
#      38     print(f"Error inserting iframe value: {e}")
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:744, in Connection._read_packet(self, packet_type)
#     742 buff = bytearray()
#     743 while True:
# --> 744     packet_header = self._read_bytes(4)
#     745     # if DEBUG: dump_packet(packet_header)
#     747     btrl, btrh, packet_number = struct.unpack("<HBB", packet_header)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:782, in Connection._read_bytes(self, num_bytes)
#     780 while True:
#     781     try:
# --> 782         data = self._rfile.read(num_bytes)
#     783         break
#     784     except OSError as e:
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import pandas as pd
import pymysql
from tqdm import tqdm

# CSV 파일 경로
csv_file_path = "iframe_link_full_전처리.csv"

# CSV 파일 읽기
df = pd.read_csv(csv_file_path)

# 필요한 데이터 추출
you_df = df[['youtube']]

# MySQL 연결 설정
conn = pymysql.connect(
    host='project-db-cgi.smhrd.com',
    port=3307,
    user='ehroqkfdbcah',
    password='q1w2e3!@#',
    db='ehroqkfdbcah',
    charset='utf8'
)

# MySQL 커서 생성
cursor = conn.cursor()

# 데이터프레임을 반복하면서 업데이트 쿼리 실행
for index, row in tqdm(you_df.iterrows(), total=you_df.shape[0]):
    music_id = index + 1  # 인덱스를 musicId로 사용 (1부터 시작)
    iframe_value = row['youtube']  # 'youtube' 열의 값
    try:
        cursor.execute("UPDATE tb_music SET iframe = %s WHERE musicIdx = %s;", (iframe_value, music_id))
        # 각 쿼리 실행 후 커밋
        conn.commit()
    except pymysql.MySQLError as e:
        print(f"Error updating iframe value for musicId {music_id}: {e}")

# MySQL 연결 종료
conn.close()
# Out:
#  15%|███████████▍                                                               | 2848/18652 [21:40<2:21:00,  1.87it/s]
